# %%
import numpy as np
import pandas as pd
import os 
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")
import psycopg2
from sqlalchemy import create_engine

# %%
bills = pd.read_csv("Data/bills.csv")
congress_members= pd.read_csv("Data/congress_members.csv")
os_legislators= pd.read_csv("Data/os_legislators.csv")
committee_members= pd.read_csv("Data/committee_members.csv")
leadership= pd.read_csv("Data/leadership.csv")
terms= pd.read_csv("Data/terms.csv")
committees= pd.read_csv("Data/committees.csv")
os_contributions= pd.read_csv("Data/os_contributions.csv")
votingaffinity= pd.read_csv("Data/votingaffinity.csv")

# %% [markdown]
# # bills

# %%
bills.columns =[x.lower() for x in bills.columns]
bills.columns =[x.replace('.','_') for x in bills.columns]
bills.columns
# Out:
# Index(['congress', 'introduceddate', 'number', 'title', 'type', 'url',
#        'latestaction_actiondate', 'latestaction_text', 'policyarea_name',
#        'amendmentnumber', 'latestaction', 'latestaction_actiontime'],
#       dtype='object')

# %%
# primary key composed of congress, number and type.
bills.head()
# Out:
#    congress introduceddate  number  \
# 0       118     2023-10-04   405.0
# 1       118     2023-09-29  2998.0
# 2       118     2023-09-27   373.0
# 3       118     2023-09-27  2937.0
# 4       118     2023-09-20  2874.0
#
#                                                title  type  \
# 0  A resolution expressing support for the design...  SRES
# 1  Land-Grant Research Equity and Accountability Act     S
# 2  A resolution designating the week of September...  SRES
# 3    Increasing American Ferrosilicon Production Act     S
# 4       Fresh Produce Procurement Reform Act of 2023     S
#
#                                                  url latestaction_actiondate  \
# 0  https://api.congress.gov/v3/bill/118/sres/405?...              2023-10-04
# 1  https://api.congress.gov/v3/bill/118/s/2998?fo...              2023-09-29
# 2  https://api.congress.gov/v3/bill/118/sres/373?...              2023-09-27
# 3  https://api.congress.gov/v3/bill/118/s/2937?fo...              2023-09-27
# 4  https://api.congress.gov/v3/bill/118/s/2874?fo...              2023-09-20
#
#                                    latestaction_text  \
# 0  Submitted in the Senate, considered, and agree...
# 1  Read twice and referred to the Committee on Ag...
# 2  Submitted in the Senate, considered, and agree...
# 3  Read twice and referred to the Committee on Fi...
# 4  Read twice and referred to the Committee on Ag...
#
#                            policyarea_name  amendmentnumber  latestaction  \
# 0       Armed Forces and National Security              NaN           NaN
# 1                     Agriculture and Food              NaN           NaN
# 2                                      NaN              NaN           NaN
# 3  Foreign Trade and International Finance              NaN           NaN
# 4                     Agriculture and Food              NaN           NaN
#
#    latestaction_actiontime
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %% [markdown]
# # congress_members

# %%
congress_members.columns =[x.lower() for x in congress_members.columns]
congress_members.columns =[x.replace('.','_') for x in congress_members.columns]
congress_members.columns
# Out:
# Index(['bioguideid', 'birthyear', 'currentmember', 'directordername',
#        'firstname', 'honorificname', 'invertedordername', 'lastname',
#        'officialwebsiteurl', 'partyhistory', 'state', 'terms', 'updatedate',
#        'addressinformation_city', 'addressinformation_district',
#        'addressinformation_officeaddress', 'addressinformation_phonenumber',
#        'addressinformation_zipcode', 'cosponsoredlegislation_count',
#        'cosponsoredlegislation_url', 'depiction_attribution',
#        'depiction_imageurl', 'sponsoredlegislation_count',
#        'sponsoredlegislation_url', 'middlename', 'suffixname', 'nickname',
#        'leadership', 'district'],
#       dtype='object')

# %%
congress_members
# Out:
#     bioguideid  birthyear  currentmember        directordername firstname  \
# 0      B000944       1952           True          Sherrod Brown   Sherrod
# 1      C000127       1958           True         Maria Cantwell     Maria
# 2      C000141       1943           True     Benjamin L. Cardin       Ben
# 3      C000174       1947           True       Thomas R. Carper    Thomas
# 4      C001070       1960           True    Robert P. Casey Jr.       Bob
# ..         ...        ...            ...                    ...       ...
# 532    V000135       1969           True      Derrick Van Orden   Derrick
# 533    H001096       1962           True     Harriet M. Hageman   Harriet
# 534    R000618       1964           True          Pete Ricketts      Pete
# 535    M001227       1972           True  Jennifer L. McClellan  Jennifer
# 536    B001320       1979           True     Laphonza R. Butler  Laphonza
#
#     honorificname       invertedordername   lastname  \
# 0             Mr.          Brown, Sherrod      Brown
# 1             Ms.         Cantwell, Maria   Cantwell
# 2             Mr.     Cardin, Benjamin L.     Cardin
# 3             Mr.       Carper, Thomas R.     Carper
# 4             Mr.   Casey, Robert P., Jr.      Casey
# ..            ...                     ...        ...
# 532           Mr.      Van Orden, Derrick  Van Orden
# 533           NaN     Hageman, Harriet M.    Hageman
# 534           Mr.          Ricketts, Pete   Ricketts
# 535           NaN  McClellan, Jennifer L.  McClellan
# 536           Ms.     Butler, Laphonza R.     Butler
#
#                   officialwebsiteurl  \
# 0      https://www.brown.senate.gov/
# 1    https://www.cantwell.senate.gov
# 2     https://www.cardin.senate.gov/
# 3      https://www.carper.senate.gov
# 4      https://www.casey.senate.gov/
# ..                               ...
# 532       https://vanorden.house.gov
# 533        https://hageman.house.gov
# 534  https://www.ricketts.senate.gov
# 535     https://mcclellan.house.gov/
# 536   https://www.butler.senate.gov/
#
#                                           partyhistory  ...  \
# 0    [{'partyAbbreviation': 'D', 'partyName': 'Demo...  ...
# 1    [{'partyAbbreviation': 'D', 'partyName': 'Demo...  ...
# 2    [{'partyAbbreviation': 'D', 'partyName': 'Demo...  ...
# 3    [{'partyAbbreviation': 'D', 'partyName': 'Demo...  ...
# 4    [{'partyAbbreviation': 'D', 'partyName': 'Demo...  ...
# ..                                                 ...  ...
# 532  [{'partyAbbreviation': 'R', 'partyName': 'Repu...  ...
# 533  [{'partyAbbreviation': 'R', 'partyName': 'Repu...  ...
# 534  [{'partyAbbreviation': 'R', 'partyName': 'Repu...  ...
# 535  [{'partyAbbreviation': 'D', 'partyName': 'Demo...  ...
# 536  [{'partyAbbreviation': 'D', 'partyName': 'Demo...  ...
#
#                             cosponsoredlegislation_url  \
# 0    https://api.congress.gov/v3/member/B000944/cos...
# 1    https://api.congress.gov/v3/member/C000127/cos...
# 2    https://api.congress.gov/v3/member/C000141/cos...
# 3    https://api.congress.gov/v3/member/C000174/cos...
# 4    https://api.congress.gov/v3/member/C001070/cos...
# ..                                                 ...
# 532  https://api.congress.gov/v3/member/V000135/cos...
# 533  https://api.congress.gov/v3/member/H001096/cos...
# 534  https://api.congress.gov/v3/member/R000618/cos...
# 535  https://api.congress.gov/v3/member/M001227/cos...
# 536  https://api.congress.gov/v3/member/B001320/cos...
#
#                                  depiction_attribution  \
# 0    <a href="http://www.senate.gov/artandhistory/h...
# 1    <a href="http://www.senate.gov/artandhistory/h...
# 2    <a href="http://www.senate.gov/artandhistory/h...
# 3    <a href="http://www.senate.gov/artandhistory/h...
# 4    <a href="http://www.senate.gov/artandhistory/h...
# ..                                                 ...
# 532                       Image courtesy of the Member
# 533                       Image courtesy of the Member
# 534                         Official U.S. Senate Photo
# 535                       Image courtesy of the Member
# 536                                                NaN
#
#                                     depiction_imageurl  \
# 0    https://www.congress.gov/img/member/b000944_20...
# 1    https://www.congress.gov/img/member/c000127_20...
# 2    https://www.congress.gov/img/member/c000141_20...
# 3    https://www.congress.gov/img/member/c000174_20...
# 4    https://www.congress.gov/img/member/c001070_20...
# ..                                                 ...
# 532  https://www.congress.gov/img/member/v000135_20...
# 533  https://www.congress.gov/img/member/h001096_20...
# 534  https://www.congress.gov/img/member/r000618_20...
# 535  https://www.congress.gov/img/member/m001227_20...
# 536                                                NaN
#
#     sponsoredlegislation_count  \
# 0                       1389.0
# 1                        882.0
# 2                       1265.0
# 3                        769.0
# 4                       1180.0
# ..                         ...
# 532                       14.0
# 533                       28.0
# 534                       17.0
# 535                        5.0
# 536                        NaN
#
#                               sponsoredlegislation_url middlename suffixname  \
# 0    https://api.congress.gov/v3/member/B000944/spo...        NaN        NaN
# 1    https://api.congress.gov/v3/member/C000127/spo...        NaN        NaN
# 2    https://api.congress.gov/v3/member/C000141/spo...        NaN        NaN
# 3    https://api.congress.gov/v3/member/C000174/spo...         R.        NaN
# 4    https://api.congress.gov/v3/member/C001070/spo...        NaN        JR.
# ..                                                 ...        ...        ...
# 532  https://api.congress.gov/v3/member/V000135/spo...        NaN        NaN
# 533  https://api.congress.gov/v3/member/H001096/spo...         M.        NaN
# 534  https://api.congress.gov/v3/member/R000618/spo...        NaN        NaN
# 535  https://api.congress.gov/v3/member/M001227/spo...         L.        NaN
# 536                                                NaN        NaN        NaN
#
#      nickname  leadership district
# 0         NaN         NaN      NaN
# 1         NaN         NaN      NaN
# 2         NaN         NaN      NaN
# 3         NaN         NaN      NaN
# 4         NaN         NaN      NaN
# ..        ...         ...      ...
# 532       NaN         NaN      3.0
# 533       NaN         NaN      NaN
# 534       NaN         NaN      NaN
# 535       NaN         NaN      4.0
# 536       NaN         NaN      NaN
#
# [537 rows x 29 columns]

# %% [markdown]
# ## terms

# %%
terms.columns =[x.lower() for x in terms.columns]
terms.columns =[x.replace('.','_') for x in terms.columns]
terms.columns
# Out:
# Index(['chamber', 'congress', 'endyear', 'membertype', 'startyear',
#        'statecode', 'statename', 'bioguideid', 'district'],
#       dtype='object')

# %% [markdown]
# ## Leadership

# %%
leadership.columns =[x.lower() for x in leadership.columns]
leadership.columns =[x.replace('.','_') for x in leadership.columns]
leadership.columns
# Out:
# Index(['congress', 'type', 'bioguideid', 'current'], dtype='object')

# %%
congress_members = congress_members.drop(['terms','leadership','partyhistory'],axis = 1)

# %%
congress_members
# Out:
#     bioguideid  birthyear  currentmember        directordername firstname  \
# 0      B000944       1952           True          Sherrod Brown   Sherrod
# 1      C000127       1958           True         Maria Cantwell     Maria
# 2      C000141       1943           True     Benjamin L. Cardin       Ben
# 3      C000174       1947           True       Thomas R. Carper    Thomas
# 4      C001070       1960           True    Robert P. Casey Jr.       Bob
# ..         ...        ...            ...                    ...       ...
# 532    V000135       1969           True      Derrick Van Orden   Derrick
# 533    H001096       1962           True     Harriet M. Hageman   Harriet
# 534    R000618       1964           True          Pete Ricketts      Pete
# 535    M001227       1972           True  Jennifer L. McClellan  Jennifer
# 536    B001320       1979           True     Laphonza R. Butler  Laphonza
#
#     honorificname       invertedordername   lastname  \
# 0             Mr.          Brown, Sherrod      Brown
# 1             Ms.         Cantwell, Maria   Cantwell
# 2             Mr.     Cardin, Benjamin L.     Cardin
# 3             Mr.       Carper, Thomas R.     Carper
# 4             Mr.   Casey, Robert P., Jr.      Casey
# ..            ...                     ...        ...
# 532           Mr.      Van Orden, Derrick  Van Orden
# 533           NaN     Hageman, Harriet M.    Hageman
# 534           Mr.          Ricketts, Pete   Ricketts
# 535           NaN  McClellan, Jennifer L.  McClellan
# 536           Ms.     Butler, Laphonza R.     Butler
#
#                   officialwebsiteurl         state  ...  \
# 0      https://www.brown.senate.gov/          Ohio  ...
# 1    https://www.cantwell.senate.gov    Washington  ...
# 2     https://www.cardin.senate.gov/      Maryland  ...
# 3      https://www.carper.senate.gov      Delaware  ...
# 4      https://www.casey.senate.gov/  Pennsylvania  ...
# ..                               ...           ...  ...
# 532       https://vanorden.house.gov     Wisconsin  ...
# 533        https://hageman.house.gov       Wyoming  ...
# 534  https://www.ricketts.senate.gov      Nebraska  ...
# 535     https://mcclellan.house.gov/      Virginia  ...
# 536   https://www.butler.senate.gov/    California  ...
#
#     cosponsoredlegislation_count  \
# 0                           7873
# 1                           3923
# 2                           6100
# 3                           4476
# 4                           3922
# ..                           ...
# 532                          103
# 533                          163
# 534                          169
# 535                          209
# 536                            9
#
#                             cosponsoredlegislation_url  \
# 0    https://api.congress.gov/v3/member/B000944/cos...
# 1    https://api.congress.gov/v3/member/C000127/cos...
# 2    https://api.congress.gov/v3/member/C000141/cos...
# 3    https://api.congress.gov/v3/member/C000174/cos...
# 4    https://api.congress.gov/v3/member/C001070/cos...
# ..                                                 ...
# 532  https://api.congress.gov/v3/member/V000135/cos...
# 533  https://api.congress.gov/v3/member/H001096/cos...
# 534  https://api.congress.gov/v3/member/R000618/cos...
# 535  https://api.congress.gov/v3/member/M001227/cos...
# 536  https://api.congress.gov/v3/member/B001320/cos...
#
#                                  depiction_attribution  \
# 0    <a href="http://www.senate.gov/artandhistory/h...
# 1    <a href="http://www.senate.gov/artandhistory/h...
# 2    <a href="http://www.senate.gov/artandhistory/h...
# 3    <a href="http://www.senate.gov/artandhistory/h...
# 4    <a href="http://www.senate.gov/artandhistory/h...
# ..                                                 ...
# 532                       Image courtesy of the Member
# 533                       Image courtesy of the Member
# 534                         Official U.S. Senate Photo
# 535                       Image courtesy of the Member
# 536                                                NaN
#
#                                     depiction_imageurl  \
# 0    https://www.congress.gov/img/member/b000944_20...
# 1    https://www.congress.gov/img/member/c000127_20...
# 2    https://www.congress.gov/img/member/c000141_20...
# 3    https://www.congress.gov/img/member/c000174_20...
# 4    https://www.congress.gov/img/member/c001070_20...
# ..                                                 ...
# 532  https://www.congress.gov/img/member/v000135_20...
# 533  https://www.congress.gov/img/member/h001096_20...
# 534  https://www.congress.gov/img/member/r000618_20...
# 535  https://www.congress.gov/img/member/m001227_20...
# 536                                                NaN
#
#     sponsoredlegislation_count  \
# 0                       1389.0
# 1                        882.0
# 2                       1265.0
# 3                        769.0
# 4                       1180.0
# ..                         ...
# 532                       14.0
# 533                       28.0
# 534                       17.0
# 535                        5.0
# 536                        NaN
#
#                               sponsoredlegislation_url  middlename suffixname  \
# 0    https://api.congress.gov/v3/member/B000944/spo...         NaN        NaN
# 1    https://api.congress.gov/v3/member/C000127/spo...         NaN        NaN
# 2    https://api.congress.gov/v3/member/C000141/spo...         NaN        NaN
# 3    https://api.congress.gov/v3/member/C000174/spo...          R.        NaN
# 4    https://api.congress.gov/v3/member/C001070/spo...         NaN        JR.
# ..                                                 ...         ...        ...
# 532  https://api.congress.gov/v3/member/V000135/spo...         NaN        NaN
# 533  https://api.congress.gov/v3/member/H001096/spo...          M.        NaN
# 534  https://api.congress.gov/v3/member/R000618/spo...         NaN        NaN
# 535  https://api.congress.gov/v3/member/M001227/spo...          L.        NaN
# 536                                                NaN         NaN        NaN
#
#     nickname district
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 532      NaN      3.0
# 533      NaN      NaN
# 534      NaN      NaN
# 535      NaN      4.0
# 536      NaN      NaN
#
# [537 rows x 26 columns]

# %%
leadership
# Out:
#     congress                         type bioguideid current
# 0        113  Assistant Democratic Leader    C001056     NaN
# 1        114    Assistant Majority Leader    C001056     NaN
# 2        115                Majority Whip    C001056     NaN
# 3        113    Assistant Majority Leader    D000563     NaN
# 4        112    Assistant Majority Leader    D000563     NaN
# ..       ...                          ...        ...     ...
# 74       118   Democratic Caucus Chairman    A000371    True
# 75       118                Majority Whip    E000294    True
# 76       117  Republican Conference Chair    S001196     NaN
# 77       118  Republican Conference Chair    S001196    True
# 78       118         Speaker of the House    J000299    True
#
# [79 rows x 4 columns]

# %% [markdown]
# ## os_legislators

# %%
os_legislators.columns =[x.lower() for x in os_legislators.columns]
os_legislators.columns =[x.replace('.','_') for x in os_legislators.columns]
os_legislators = os_legislators.drop_duplicates()

# %%
newbio = ['B001311','B001313','B001314','B001315','C001125',
          'C001126','C001127','C001129','E000071','F000475','G000061',
          'G000551','G000595','H001093','L000595','L000597','M000687',
          'M001210','M001217','M001227','R000579','R000618',
          'S001218','T000165','T000488','P000619']
legs = ['Dan Bishop','Shontel Brown','Aaron Bean','Nikki Budzinski',
        'Troy Carter','Mike Carey','Sheila Cherfilus-McCormick',
        'Mike Collins','Jake Ellzey','Brad Finstad','Mike Garcia',
        'Raul M Grijalva','Bob Good','Erin Houchin','Julia Letlow',
        'Laurel Lee','Kweisi Mfume','Greg Murphy','Jared Moskowitz',
        'Jennifer McClellan','Pat Ryan','Pete Ricketts','Melanie Stansbury',
        'Tom Tiffany','Shri Thanedar','Mary Peltola']
def replacebio(b,n):
    os_legislators.loc[os_legislators['firstl']==n, 'oguide_id'] = b
for b, n in zip(newbio, legs):
    replacebio(b,n)

# %%
os_legislators
# Out:
#            cid                firstl    lastnam party offic gend  \
# 0    N00050780          Mary Peltola    Peltola     D  AK01    F
# 1    N00035774          Dan Sullivan   Sullivan     R  AKS1    M
# 2    N00026050        Lisa Murkowski  Murkowski     R  AKS2    F
# 3    N00044245            Jerry Carl       Carl     R  AL01    M
# 4    N00041295           Barry Moore      Moore     R  AL02    M
# ..         ...                   ...        ...   ...   ...  ...
# 532  N00032838           Joe Manchin    Manchin     D  WVS1    M
# 533  N00009771  Shelley Moore Capito     Capito     R  WVS2    F
# 534  N00049197       Harriet Hageman    Hageman     R  WY01    F
# 535  N00006236         John Barrasso   Barrasso     R  WYS1    M
# 536  N00029788        Cynthia Lummis     Lummis     R  WYS2    F
#
#      first_elected  xit_cod commen          phon  ...  \
# 0             2022        0    NaN           NaN  ...
# 1             2014        0    NaN  202-224-3004  ...
# 2             2002        0    NaN  202-224-6665  ...
# 3             2020        0    NaN   202225-4931  ...
# 4             2020        0    NaN   202225-2901  ...
# ..             ...      ...    ...           ...  ...
# 532           2010        0    NaN  202-224-3954  ...
# 533           2014        0    NaN  202-224-6472  ...
# 534           2022        0    NaN           NaN  ...
# 535           2007        0    NaN  202-224-6441  ...
# 536           2020        0    NaN  202-225-2311  ...
#
#                                          w  \
# 0                                      NaN
# 1          https://www.sullivan.senate.gov
# 2         https://www.murkowski.senate.gov
# 3                  https://carl.house.gov/
# 4            https://barrymoore.house.gov/
# ..                                     ...
# 532  https://www.manchin.senate.gov/public
# 533          https://www.capito.senate.gov
# 534                                    NaN
# 535        https://www.barrasso.senate.gov
# 536                http://lummis.house.gov
#
#                                                webform  \
# 0                                                  NaN
# 1        https://www.sullivan.senate.gov/contact/email
# 2    https://www.murkowski.senate.gov/public/index....
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 532  http://www.manchin.senate.gov/public/index.cfm...
# 533  https://www.capito.senate.gov/contact/contact-...
# 534                                                NaN
# 535  https://www.barrasso.senate.gov/public/index.c...
# 536                   http://lummis.house.gov/contact/
#
#                                         congress_offic oguide_id votesmart_id  \
# 0                                                  NaN   P000619          NaN
# 1                      702 Hart Senate Office Building   S001198          NaN
# 2                      522 Hart Senate Office Building   M001153      15841.0
# 3    1330 Longworth House Office Building, Washingt...   C001054          NaN
# 4    1504 Longworth House Office Building, Washingt...   M001212          NaN
# ..                                                 ...       ...          ...
# 532                    306 Hart Senate Office Building   M001183       7547.0
# 533                 172 Russell Senate Office Building   C001047      11701.0
# 534                                                NaN   H001096          NaN
# 535                 307 Dirksen Senate Office Building   B001261      52662.0
# 536                 2433 Rayburn House Office Building   L000571      15546.0
#
#      feccandid        witter_id                                   youtube_url  \
# 0          NaN              NaN                                           NaN
# 1    S4AK00214   SenDanSullivan                                           NaN
# 2    S4AK00099    LisaMurkowski          https://youtube.com/senatormurkowski
# 3          NaN    @RepJerryCarl                                           NaN
# 4          NaN   @RepBarryMoore                                           NaN
# ..         ...              ...                                           ...
# 532  S0WV00090   Sen_JoeManchin         https://youtube.com/SenatorJoeManchin
# 533  H0WV02138        SenCapito  https://youtube.com/UCbiXdR4XQ3vD9Xp5lfR9QXw
# 534  H2WY00166              NaN                                           NaN
# 535  S6WY00068  SenJohnBarrasso               https://youtube.com/barrassowyo
# 536  H8WY00148    CynthiaLummis              http://youtube.com/CynthiaLummis
#
#           facebook_id          hd
# 0                 NaN         NaN
# 1      SenDanSullivan  1964-11-13
# 2    SenLisaMurkowski  1957-05-22
# 3        RepJerryCarl    06/17/58
# 4                 NaN    09/02/66
# ..                ...         ...
# 532     JoeManchinIII  1947-08-24
# 533        senshelley  1953-11-26
# 534               NaN         NaN
# 535      johnbarrasso  1952-07-21
# 536               NaN  1954-09-10
#
# [536 rows x 21 columns]

# %%
os_legislators = os_legislators[['cid','party','oguide_id']]
os_legislators = os_legislators.rename({'oguide_id':'bioguideid'},axis = 1)
os_legislators
# Out:
#            cid party bioguideid
# 0    N00050780     D    P000619
# 1    N00035774     R    S001198
# 2    N00026050     R    M001153
# 3    N00044245     R    C001054
# 4    N00041295     R    M001212
# ..         ...   ...        ...
# 532  N00032838     D    M001183
# 533  N00009771     R    C001047
# 534  N00049197     R    H001096
# 535  N00006236     R    B001261
# 536  N00029788     R    L000571
#
# [536 rows x 3 columns]

# %%
members = pd.merge(congress_members, os_legislators, on = 'bioguideid', how = "outer", validate = 'one_to_one', indicator = 'matched')

# %%
members
# Out:
#     bioguideid  birthyear currentmember      directordername firstname  \
# 0      B000944     1952.0          True        Sherrod Brown   Sherrod
# 1      C000127     1958.0          True       Maria Cantwell     Maria
# 2      C000141     1943.0          True   Benjamin L. Cardin       Ben
# 3      C000174     1947.0          True     Thomas R. Carper    Thomas
# 4      C001070     1960.0          True  Robert P. Casey Jr.       Bob
# ..         ...        ...           ...                  ...       ...
# 538    F000062        NaN           NaN                  NaN       NaN
# 539    C001129        NaN           NaN                  NaN       NaN
# 540    S001197        NaN           NaN                  NaN       NaN
# 541    C001084        NaN           NaN                  NaN       NaN
# 542    S001192        NaN           NaN                  NaN       NaN
#
#     honorificname      invertedordername  lastname  \
# 0             Mr.         Brown, Sherrod     Brown
# 1             Ms.        Cantwell, Maria  Cantwell
# 2             Mr.    Cardin, Benjamin L.    Cardin
# 3             Mr.      Carper, Thomas R.    Carper
# 4             Mr.  Casey, Robert P., Jr.     Casey
# ..            ...                    ...       ...
# 538           NaN                    NaN       NaN
# 539           NaN                    NaN       NaN
# 540           NaN                    NaN       NaN
# 541           NaN                    NaN       NaN
# 542           NaN                    NaN       NaN
#
#                   officialwebsiteurl         state  ...  \
# 0      https://www.brown.senate.gov/          Ohio  ...
# 1    https://www.cantwell.senate.gov    Washington  ...
# 2     https://www.cardin.senate.gov/      Maryland  ...
# 3      https://www.carper.senate.gov      Delaware  ...
# 4      https://www.casey.senate.gov/  Pennsylvania  ...
# ..                               ...           ...  ...
# 538                              NaN           NaN  ...
# 539                              NaN           NaN  ...
# 540                              NaN           NaN  ...
# 541                              NaN           NaN  ...
# 542                              NaN           NaN  ...
#
#                                     depiction_imageurl  \
# 0    https://www.congress.gov/img/member/b000944_20...
# 1    https://www.congress.gov/img/member/c000127_20...
# 2    https://www.congress.gov/img/member/c000141_20...
# 3    https://www.congress.gov/img/member/c000174_20...
# 4    https://www.congress.gov/img/member/c001070_20...
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#     sponsoredlegislation_count  \
# 0                       1389.0
# 1                        882.0
# 2                       1265.0
# 3                        769.0
# 4                       1180.0
# ..                         ...
# 538                        NaN
# 539                        NaN
# 540                        NaN
# 541                        NaN
# 542                        NaN
#
#                               sponsoredlegislation_url middlename suffixname  \
# 0    https://api.congress.gov/v3/member/B000944/spo...        NaN        NaN
# 1    https://api.congress.gov/v3/member/C000127/spo...        NaN        NaN
# 2    https://api.congress.gov/v3/member/C000141/spo...        NaN        NaN
# 3    https://api.congress.gov/v3/member/C000174/spo...         R.        NaN
# 4    https://api.congress.gov/v3/member/C001070/spo...        NaN        JR.
# ..                                                 ...        ...        ...
# 538                                                NaN        NaN        NaN
# 539                                                NaN        NaN        NaN
# 540                                                NaN        NaN        NaN
# 541                                                NaN        NaN        NaN
# 542                                                NaN        NaN        NaN
#
#      nickname  district        cid party     matched
# 0         NaN       NaN  N00003535     D        both
# 1         NaN       NaN  N00007836     D        both
# 2         NaN       NaN  N00001955     D        both
# 3         NaN       NaN  N00012508     D        both
# 4         NaN       NaN  N00027503     D        both
# ..        ...       ...        ...   ...         ...
# 538       NaN       NaN  N00007364     D  right_only
# 539       NaN       NaN  N00035370     R  right_only
# 540       NaN       NaN  N00035544     R  right_only
# 541       NaN       NaN  N00032019     D  right_only
# 542       NaN       NaN  N00033932     R  right_only
#
# [543 rows x 29 columns]

# %%
members['matched'].value_counts()
# Out:
# matched
# both          530
# left_only       7
# right_only      6
# Name: count, dtype: int64

# %%
members = pd.merge(congress_members, os_legislators, on = 'bioguideid', how = 'inner')

# %%
members
# Out:
#     bioguideid  birthyear  currentmember          directordername firstname  \
# 0      B000944       1952           True            Sherrod Brown   Sherrod
# 1      C000127       1958           True           Maria Cantwell     Maria
# 2      C000141       1943           True       Benjamin L. Cardin       Ben
# 3      C000174       1947           True         Thomas R. Carper    Thomas
# 4      C001070       1960           True      Robert P. Casey Jr.       Bob
# ..         ...        ...            ...                      ...       ...
# 525    G000600       1988           True  Marie Gluesenkamp Perez     Marie
# 526    V000135       1969           True        Derrick Van Orden   Derrick
# 527    H001096       1962           True       Harriet M. Hageman   Harriet
# 528    R000618       1964           True            Pete Ricketts      Pete
# 529    M001227       1972           True    Jennifer L. McClellan  Jennifer
#
#     honorificname         invertedordername   lastname  \
# 0             Mr.            Brown, Sherrod      Brown
# 1             Ms.           Cantwell, Maria   Cantwell
# 2             Mr.       Cardin, Benjamin L.     Cardin
# 3             Mr.         Carper, Thomas R.     Carper
# 4             Mr.     Casey, Robert P., Jr.      Casey
# ..            ...                       ...        ...
# 525           NaN  Perez, Marie Gluesenkamp      Perez
# 526           Mr.        Van Orden, Derrick  Van Orden
# 527           NaN       Hageman, Harriet M.    Hageman
# 528           Mr.            Ricketts, Pete   Ricketts
# 529           NaN    McClellan, Jennifer L.  McClellan
#
#                      officialwebsiteurl         state  ...  \
# 0         https://www.brown.senate.gov/          Ohio  ...
# 1       https://www.cantwell.senate.gov    Washington  ...
# 2        https://www.cardin.senate.gov/      Maryland  ...
# 3         https://www.carper.senate.gov      Delaware  ...
# 4         https://www.casey.senate.gov/  Pennsylvania  ...
# ..                                  ...           ...  ...
# 525  https://gluesenkampperez.house.gov    Washington  ...
# 526          https://vanorden.house.gov     Wisconsin  ...
# 527           https://hageman.house.gov       Wyoming  ...
# 528     https://www.ricketts.senate.gov      Nebraska  ...
# 529        https://mcclellan.house.gov/      Virginia  ...
#
#                                  depiction_attribution  \
# 0    <a href="http://www.senate.gov/artandhistory/h...
# 1    <a href="http://www.senate.gov/artandhistory/h...
# 2    <a href="http://www.senate.gov/artandhistory/h...
# 3    <a href="http://www.senate.gov/artandhistory/h...
# 4    <a href="http://www.senate.gov/artandhistory/h...
# ..                                                 ...
# 525                       Image courtesy of the Member
# 526                       Image courtesy of the Member
# 527                       Image courtesy of the Member
# 528                         Official U.S. Senate Photo
# 529                       Image courtesy of the Member
#
#                                     depiction_imageurl  \
# 0    https://www.congress.gov/img/member/b000944_20...
# 1    https://www.congress.gov/img/member/c000127_20...
# 2    https://www.congress.gov/img/member/c000141_20...
# 3    https://www.congress.gov/img/member/c000174_20...
# 4    https://www.congress.gov/img/member/c001070_20...
# ..                                                 ...
# 525  https://www.congress.gov/img/member/g000600_20...
# 526  https://www.congress.gov/img/member/v000135_20...
# 527  https://www.congress.gov/img/member/h001096_20...
# 528  https://www.congress.gov/img/member/r000618_20...
# 529  https://www.congress.gov/img/member/m001227_20...
#
#     sponsoredlegislation_count  \
# 0                       1389.0
# 1                        882.0
# 2                       1265.0
# 3                        769.0
# 4                       1180.0
# ..                         ...
# 525                       13.0
# 526                       14.0
# 527                       28.0
# 528                       17.0
# 529                        5.0
#
#                               sponsoredlegislation_url   middlename  \
# 0    https://api.congress.gov/v3/member/B000944/spo...          NaN
# 1    https://api.congress.gov/v3/member/C000127/spo...          NaN
# 2    https://api.congress.gov/v3/member/C000141/spo...          NaN
# 3    https://api.congress.gov/v3/member/C000174/spo...           R.
# 4    https://api.congress.gov/v3/member/C001070/spo...          NaN
# ..                                                 ...          ...
# 525  https://api.congress.gov/v3/member/G000600/spo...  Gluesenkamp
# 526  https://api.congress.gov/v3/member/V000135/spo...          NaN
# 527  https://api.congress.gov/v3/member/H001096/spo...           M.
# 528  https://api.congress.gov/v3/member/R000618/spo...          NaN
# 529  https://api.congress.gov/v3/member/M001227/spo...           L.
#
#      suffixname  nickname district        cid party
# 0           NaN       NaN      NaN  N00003535     D
# 1           NaN       NaN      NaN  N00007836     D
# 2           NaN       NaN      NaN  N00001955     D
# 3           NaN       NaN      NaN  N00012508     D
# 4           JR.       NaN      NaN  N00027503     D
# ..          ...       ...      ...        ...   ...
# 525         NaN       NaN      3.0  N00050490     D
# 526         NaN       NaN      3.0  N00046843     R
# 527         NaN       NaN      NaN  N00049197     R
# 528         NaN       NaN      NaN  N00027695     R
# 529         NaN       NaN      4.0  N00051961     D
#
# [530 rows x 28 columns]

# %% [markdown]
# ## contributions

# %%
os_contributions.columns =[x.lower() for x in os_contributions.columns]
os_contributions.columns =[x.replace('.','_') for x in os_contributions.columns]
os_contributions = os_contributions.rename({'otal': 'total',
                                           'org_nam': 'org_name'}, axis=1)
os_contributions.head(30)
# Out:
#                                  org_name  total    pac   ndiv        cid
# 0                         State of Alaska  19541      0  19541  N00050780
# 1                 Sonosky, Chambers et al  16050      0  16050  N00050780
# 2               General Communication Inc  15150   2500  12650  N00050780
# 3                              Google Inc  14164      0  14164  N00050780
# 4          University of Alaska/Anchorage  13938      0  13938  N00050780
# 5                              Swing Left  13400      0  13400  N00050780
# 6                               Apple Inc  10783      0  10783  N00050780
# 7   Service Employees International Union  10010   5000   5010  N00050780
# 8                 National Education Assn  10000  10000      0  N00050780
# 9                           Sealaska Corp   9950      0   9950  N00050780
# 10                      Rpm International  66950  10000  56950  N00035774
# 11                          Goldman Sachs  59500   4000  55500  N00035774
# 12              Calfee, Halter & Griswold  45300      0  45300  N00035774
# 13    National Republican Senatorial Cmte  44600  44600      0  N00035774
# 14                       Trident Seafoods  43550   5600  37950  N00035774
# 15                     Elliott Management  39100      0  39100  N00035774
# 16                        General Atomics  37550  12500  25050  N00035774
# 17                         ConocoPhillips  37425  10000  27425  N00035774
# 18                       Blackstone Group  36100      0  36100  N00035774
# 19                             Lynden Inc  30700      0  30700  N00035774
# 20                         ConocoPhillips  60050  10000  50050  N00026050
# 21    American Israel Public Affairs Cmte  59500  10000  49500  N00026050
# 22                       Trident Seafoods  55300   5800  49500  N00026050
# 23    National Republican Senatorial Cmte  51200  51200      0  N00026050
# 24                               KKR & Co  48405      0  48405  N00026050
# 25                         NextEra Energy  36450  10000  26450  N00026050
# 26              General Communication Inc  34900  10000  24900  N00026050
# 27                            Exelon Corp  34300  11500  22800  N00026050
# 28                                 NorPAC  31250      0  31250  N00026050
# 29                          Capital Group  30700      0  30700  N00026050

# %%
os_contributions
# Out:
#                                  org_name  total    pac   ndiv        cid
# 0                         State of Alaska  19541      0  19541  N00050780
# 1                 Sonosky, Chambers et al  16050      0  16050  N00050780
# 2               General Communication Inc  15150   2500  12650  N00050780
# 3                              Google Inc  14164      0  14164  N00050780
# 4          University of Alaska/Anchorage  13938      0  13938  N00050780
# ...                                   ...    ...    ...    ...        ...
# 1985  New York Cancer & Blood Specialists  15000      0  15000  N00038260
# 1986                      Transdigm Group  15000  10000   5000  N00038260
# 1987                         Altria Group  12900  10000   2900  N00038260
# 1988                            LHC Group  11800   5000   6800  N00038260
# 1989                       Brymak & Assoc  11600      0  11600  N00038260
#
# [1990 rows x 5 columns]

# %% [markdown]
# ## committees

# %%
committees.columns =[x.lower() for x in committees.columns]
committees.columns =[x.replace('.','_') for x in committees.columns]
committees.columns
# Out:
# Index(['chamber', 'committeetypecode', 'name', 'systemcode', 'url',
#        'parent_name', 'parent_systemcode', 'parent_url', 'subcommittees'],
#       dtype='object')

# %%
committees = committees.drop(['subcommittees'],axis = 1)

# %%
committees['systemcode'] = [x[:-2].upper() for x in committees['systemcode']]

# %% [markdown]
# ## committee_members

# %%
committee_members.columns =[x.lower() for x in committee_members.columns]
committee_members.columns =[x.replace('.','_') for x in committee_members.columns]
committee_members.columns
# Out:
# Index(['committee_code', 'rank', 'title', 'bioguide'], dtype='object')

# %%
committee_members
# Out:
#      committee_code  rank           title bioguide
# 0              HSII   1.0           Chair  W000821
# 1              HSII   1.0  Ranking Member  G000551
# 2              HSII   2.0             NaN  L000564
# 3              HSII   2.0             NaN  N000179
# 4              HSII   3.0             NaN  W000804
# ...             ...   ...             ...      ...
# 3861         HSBA10   6.0             NaN  V000130
# 3862         HSBA10   7.0             NaN  N000193
# 3863         HSBA10   7.0             NaN  G000583
# 3864         HSBA10   8.0             NaN  D000594
# 3865         HSBA10   9.0             NaN  O000175
#
# [3866 rows x 4 columns]

# %% [markdown]
# ## create the database

# %%
dbserver = psycopg2.connect(
    host = 'postgres',
    user = 'postgres',
    password = POSTGRES_PASSWORD,
    port = 5432
)
dbserver.autocommit= True

# %%
cursor = dbserver.cursor()

# %%
try:
    cursor.execute('CREATE DATABASE congress')
except:
    cursor.execute('DROP DATABASE congress')
    cursor.execute('CREATE DATABASE congress')

# %%
engine =  create_engine('postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}'.format(
    user = "postgres",
    password = POSTGRES_PASSWORD,
    host = 'postgres',
    port = 5432,
    db = 'congress'
))

# %% [markdown]
# we need to upload
#
# * members
# * bills
# * committees
# * committee members
# * terms
# * leadership
# * contributions

# %%
print(members.shape[0])
members.to_sql('members',con=engine, index = False, chunksize = 1000, if_exists = 'replace')
# Out:
# 530
# 530

# %%
print(bills.shape[0])
bills.to_sql('bills',con=engine, index = False, chunksize = 1000, if_exists = 'replace')
# Out:
# 38325
# 38325

# %%
print(committees.shape[0])
committees.to_sql('committees',con=engine, index = False, chunksize = 1000, if_exists = 'replace')
# Out:
# 714
# 714

# %%
print(committee_members.shape[0])
committee_members.to_sql('committee_members',con=engine, index = False, chunksize = 1000, if_exists = 'replace')
# Out:
# 3866
# 3866

# %%
print(terms.shape[0])
terms.to_sql('terms',con=engine, index = False, chunksize = 1000, if_exists = 'replace')
# Out:
# 278
# 278

# %%
print(leadership.shape[0])
leadership.to_sql('leadership',con=engine, index = False, chunksize = 1000, if_exists = 'replace')
# Out:
# 79
# 79

# %%
print(os_contributions.shape[0])
os_contributions.to_sql('contributions',con=engine, index = False, chunksize = 1000, if_exists = 'replace')
# Out:
# 1990
# 1990

# %%
committees.dtypes
# Out:
# chamber              object
# committeetypecode    object
# name                 object
# systemcode           object
# url                  object
# parent_name          object
# parent_systemcode    object
# parent_url           object
# dtype: object
