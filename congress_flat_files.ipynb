# %%
import numpy as np
import pandas as pd
import requests
from ydata_profiling import ProfileReport

# %%
url = "https://voteview.com/static/data/out/members/HSall_members.csv"
ideology = pd.read_csv(url)
ideology
# Out:
#        congress    chamber  icpsr  state_icpsr  district_code state_abbrev  \
# 0             1  President  99869           99            0.0          USA
# 1             1      House    379           44            2.0           GA
# 2             1      House   4854           44            1.0           GA
# 3             1      House   6071           44            3.0           GA
# 4             1      House   1538           52            6.0           MD
# ...         ...        ...    ...          ...            ...          ...
# 50480       118     Senate  40915           56            0.0           WV
# 50481       118     Senate  29940           25            0.0           WI
# 50482       118     Senate  41111           25            0.0           WI
# 50483       118     Senate  20953           68            0.0           WY
# 50484       118     Senate  40707           68            0.0           WY
#
#        party_code  occupancy  last_means             bioname  ...    died  \
# 0            5000        NaN         NaN  WASHINGTON, George  ...     NaN
# 1            4000        0.0         1.0    BALDWIN, Abraham  ...  1807.0
# 2            4000        0.0         1.0      JACKSON, James  ...  1806.0
# 3            4000        0.0         1.0     MATHEWS, George  ...  1812.0
# 4            5000        0.0         1.0     CARROLL, Daniel  ...  1796.0
# ...           ...        ...         ...                 ...  ...     ...
# 50480         100        NaN         NaN   MANCHIN, Joe, III  ...     NaN
# 50481         100        NaN         NaN      BALDWIN, Tammy  ...     NaN
# 50482         200        NaN         NaN        JOHNSON, Ron  ...     NaN
# 50483         200        NaN         NaN  LUMMIS, Cynthia M.  ...     NaN
# 50484         200        NaN         NaN   BARRASSO, John A.  ...     NaN
#
#        nominate_dim1  nominate_dim2  nominate_log_likelihood  \
# 0                NaN            NaN                      NaN
# 1             -0.165         -0.373                -28.55029
# 2             -0.320         -0.181                -24.89986
# 3             -0.428         -0.317                -12.62728
# 4              0.116         -0.740                -23.47008
# ...              ...            ...                      ...
# 50480         -0.058          0.407                -37.98553
# 50481         -0.492         -0.135                -10.30919
# 50482          0.629         -0.145                -21.10066
# 50483          0.692         -0.340                -23.76128
# 50484          0.537          0.224                 -7.42317
#
#        nominate_geo_mean_probability  nominate_number_of_votes  \
# 0                                NaN                       NaN
# 1                            0.75800                     103.0
# 2                            0.77600                      98.0
# 3                            0.88000                      99.0
# 4                            0.78300                      96.0
# ...                              ...                       ...
# 50480                        0.83381                     209.0
# 50481                        0.95275                     213.0
# 50482                        0.90440                     210.0
# 50483                        0.89205                     208.0
# 50484                        0.95627                     166.0
#
#        nominate_number_of_errors  conditional  nokken_poole_dim1  \
# 0                            NaN          NaN                NaN
# 1                           12.0          NaN             -0.429
# 2                            9.0          NaN             -0.559
# 3                            2.0          NaN             -0.413
# 4                           11.0          NaN              0.114
# ...                          ...          ...                ...
# 50480                       10.0          NaN             -0.019
# 50481                        5.0          NaN             -0.425
# 50482                        7.0          NaN              0.698
# 50483                       13.0          NaN              0.785
# 50484                        0.0          NaN              0.541
#
#        nokken_poole_dim2
# 0                    NaN
# 1                 -0.817
# 2                 -0.052
# 3                 -0.232
# 4                 -0.779
# ...                  ...
# 50480              0.295
# 50481             -0.214
# 50482              0.124
# 50483             -0.027
# 50484              0.603
#
# [50485 rows x 22 columns]

# %%
ideology.T
# Out:
#                                             0                 1      \
# congress                                        1                 1
# chamber                                 President             House
# icpsr                                       99869               379
# state_icpsr                                    99                44
# district_code                                 0.0               2.0
# state_abbrev                                  USA                GA
# party_code                                   5000              4000
# occupancy                                     NaN               0.0
# last_means                                    NaN               1.0
# bioname                        WASHINGTON, George  BALDWIN, Abraham
# bioguide_id                                   NaN           B000084
# born                                          NaN            1754.0
# died                                          NaN            1807.0
# nominate_dim1                                 NaN            -0.165
# nominate_dim2                                 NaN            -0.373
# nominate_log_likelihood                       NaN         -28.55029
# nominate_geo_mean_probability                 NaN             0.758
# nominate_number_of_votes                      NaN             103.0
# nominate_number_of_errors                     NaN              12.0
# conditional                                   NaN               NaN
# nokken_poole_dim1                             NaN            -0.429
# nokken_poole_dim2                             NaN            -0.817
#
#                                         2                3      \
# congress                                    1                1
# chamber                                 House            House
# icpsr                                    4854             6071
# state_icpsr                                44               44
# district_code                             1.0              3.0
# state_abbrev                               GA               GA
# party_code                               4000             4000
# occupancy                                 0.0              0.0
# last_means                                1.0              1.0
# bioname                        JACKSON, James  MATHEWS, George
# bioguide_id                           J000017          M000234
# born                                   1757.0           1739.0
# died                                   1806.0           1812.0
# nominate_dim1                           -0.32           -0.428
# nominate_dim2                          -0.181           -0.317
# nominate_log_likelihood             -24.89986        -12.62728
# nominate_geo_mean_probability           0.776             0.88
# nominate_number_of_votes                 98.0             99.0
# nominate_number_of_errors                 9.0              2.0
# conditional                               NaN              NaN
# nokken_poole_dim1                      -0.559           -0.413
# nokken_poole_dim2                      -0.052           -0.232
#
#                                          4                 5      \
# congress                                     1                 1
# chamber                                  House             House
# icpsr                                     1538              2010
# state_icpsr                                 52                52
# district_code                              6.0               3.0
# state_abbrev                                MD                MD
# party_code                                5000              4000
# occupancy                                  0.0               0.0
# last_means                                 1.0               1.0
# bioname                        CARROLL, Daniel  CONTEE, Benjamin
# bioguide_id                            C000187           C000710
# born                                    1730.0            1755.0
# died                                    1796.0            1815.0
# nominate_dim1                            0.116             -0.08
# nominate_dim2                            -0.74            -0.387
# nominate_log_likelihood              -23.47008         -21.88695
# nominate_geo_mean_probability            0.783             0.788
# nominate_number_of_votes                  96.0              92.0
# nominate_number_of_errors                 11.0              13.0
# conditional                                NaN               NaN
# nokken_poole_dim1                        0.114            -0.093
# nokken_poole_dim2                       -0.779            -0.411
#
#                                       6              7               8      \
# congress                                  1              1               1
# chamber                               House          House           House
# icpsr                                  3430           8363            8693
# state_icpsr                              52             52              52
# district_code                           5.0            2.0             4.0
# state_abbrev                             MD             MD              MD
# party_code                             5000           4000            4000
# occupancy                               0.0            0.0             0.0
# last_means                              1.0            1.0             1.0
# bioname                        GALE, George  SENEY, Joshua  SMITH, William
# bioguide_id                         G000012        S000242         S000624
# born                                 1756.0         1756.0          1728.0
# died                                 1815.0         1798.0          1814.0
# nominate_dim1                         0.254          0.221           0.393
# nominate_dim2                        -0.967           0.27           0.279
# nominate_log_likelihood           -24.12829      -58.65501       -55.83761
# nominate_geo_mean_probability         0.774          0.575           0.582
# nominate_number_of_votes               94.0          106.0           103.0
# nominate_number_of_errors              10.0           34.0            30.0
# conditional                             NaN            NaN             NaN
# nokken_poole_dim1                     0.273          0.279           0.391
# nokken_poole_dim2                    -0.962          0.309           0.285
#
#                                                 9      ...         50475  \
# congress                                            1  ...           118
# chamber                                         House  ...        Senate
# icpsr                                            8983  ...         40909
# state_icpsr                                        52  ...            40
# district_code                                     1.0  ...           0.0
# state_abbrev                                       MD  ...            VA
# party_code                                       4000  ...           100
# occupancy                                         0.0  ...           NaN
# last_means                                        1.0  ...           NaN
# bioname                        STONE, Michael Jenifer  ...  WARNER, Mark
# bioguide_id                                   S000961  ...       W000805
# born                                           1747.0  ...        1954.0
# died                                           1812.0  ...           NaN
# nominate_dim1                                   0.036  ...        -0.205
# nominate_dim2                                     0.1  ...        -0.051
# nominate_log_likelihood                     -39.88339  ...      -5.82489
# nominate_geo_mean_probability                   0.663  ...       0.97264
# nominate_number_of_votes                         97.0  ...         210.0
# nominate_number_of_errors                        20.0  ...           2.0
# conditional                                       NaN  ...           NaN
# nokken_poole_dim1                               0.039  ...        -0.308
# nokken_poole_dim2                                0.12  ...         0.011
#
#                                                       50476  \
# congress                                                118
# chamber                                              Senate
# icpsr                                                 41305
# state_icpsr                                              40
# district_code                                           0.0
# state_abbrev                                             VA
# party_code                                              100
# occupancy                                               NaN
# last_means                                              NaN
# bioname                        KAINE, Timothy Michael (Tim)
# bioguide_id                                         K000384
# born                                                 1958.0
# died                                                    NaN
# nominate_dim1                                        -0.245
# nominate_dim2                                        -0.062
# nominate_log_likelihood                            -3.78988
# nominate_geo_mean_probability                       0.98236
# nominate_number_of_votes                              213.0
# nominate_number_of_errors                               1.0
# conditional                                             NaN
# nokken_poole_dim1                                    -0.371
# nokken_poole_dim2                                     0.059
#
#                                             50477          50478  \
# congress                                      118            118
# chamber                                    Senate         Senate
# icpsr                                       39310          49308
# state_icpsr                                    73             73
# district_code                                 0.0            0.0
# state_abbrev                                   WA             WA
# party_code                                    100            100
# occupancy                                     NaN            NaN
# last_means                                    NaN            NaN
# bioname                        CANTWELL, Maria E.  MURRAY, Patty
# bioguide_id                               C000127        M001111
# born                                       1958.0         1950.0
# died                                          NaN            NaN
# nominate_dim1                              -0.305         -0.352
# nominate_dim2                              -0.411         -0.305
# nominate_log_likelihood                   -3.1924       -3.40313
# nominate_geo_mean_probability             0.98512        0.98369
# nominate_number_of_votes                    213.0          207.0
# nominate_number_of_errors                     0.0            1.0
# conditional                                   NaN            NaN
# nokken_poole_dim1                          -0.366         -0.306
# nokken_poole_dim2                          -0.158          -0.24
#
#                                                50479              50480  \
# congress                                         118                118
# chamber                                       Senate             Senate
# icpsr                                          20146              40915
# state_icpsr                                       56                 56
# district_code                                    0.0                0.0
# state_abbrev                                      WV                 WV
# party_code                                       200                100
# occupancy                                        NaN                NaN
# last_means                                       NaN                NaN
# bioname                        CAPITO, Shelley Moore  MANCHIN, Joe, III
# bioguide_id                                  C001047            M001183
# born                                          1953.0             1947.0
# died                                             NaN                NaN
# nominate_dim1                                  0.277             -0.058
# nominate_dim2                                  0.128              0.407
# nominate_log_likelihood                    -47.96918          -37.98553
# nominate_geo_mean_probability                0.79835            0.83381
# nominate_number_of_votes                       213.0              209.0
# nominate_number_of_errors                       16.0               10.0
# conditional                                      NaN                NaN
# nokken_poole_dim1                              0.282             -0.019
# nokken_poole_dim2                              0.409              0.295
#
#                                         50481         50482  \
# congress                                  118           118
# chamber                                Senate        Senate
# icpsr                                   29940         41111
# state_icpsr                                25            25
# district_code                             0.0           0.0
# state_abbrev                               WI            WI
# party_code                                100           200
# occupancy                                 NaN           NaN
# last_means                                NaN           NaN
# bioname                        BALDWIN, Tammy  JOHNSON, Ron
# bioguide_id                           B001230       J000293
# born                                   1962.0        1955.0
# died                                      NaN           NaN
# nominate_dim1                          -0.492         0.629
# nominate_dim2                          -0.135        -0.145
# nominate_log_likelihood             -10.30919     -21.10066
# nominate_geo_mean_probability         0.95275        0.9044
# nominate_number_of_votes                213.0         210.0
# nominate_number_of_errors                 5.0           7.0
# conditional                               NaN           NaN
# nokken_poole_dim1                      -0.425         0.698
# nokken_poole_dim2                      -0.214         0.124
#
#                                             50483              50484
# congress                                      118                118
# chamber                                    Senate             Senate
# icpsr                                       20953              40707
# state_icpsr                                    68                 68
# district_code                                 0.0                0.0
# state_abbrev                                   WY                 WY
# party_code                                    200                200
# occupancy                                     NaN                NaN
# last_means                                    NaN                NaN
# bioname                        LUMMIS, Cynthia M.  BARRASSO, John A.
# bioguide_id                               L000571            B001261
# born                                       1954.0             1952.0
# died                                          NaN                NaN
# nominate_dim1                               0.692              0.537
# nominate_dim2                               -0.34              0.224
# nominate_log_likelihood                 -23.76128           -7.42317
# nominate_geo_mean_probability             0.89205            0.95627
# nominate_number_of_votes                    208.0              166.0
# nominate_number_of_errors                    13.0                0.0
# conditional                                   NaN                NaN
# nokken_poole_dim1                           0.785              0.541
# nokken_poole_dim2                          -0.027              0.603
#
# [22 rows x 50485 columns]

# %%
ideology.head(3).T
# Out:
#                                                 0                 1  \
# congress                                        1                 1
# chamber                                 President             House
# icpsr                                       99869               379
# state_icpsr                                    99                44
# district_code                                 0.0               2.0
# state_abbrev                                  USA                GA
# party_code                                   5000              4000
# occupancy                                     NaN               0.0
# last_means                                    NaN               1.0
# bioname                        WASHINGTON, George  BALDWIN, Abraham
# bioguide_id                                   NaN           B000084
# born                                          NaN            1754.0
# died                                          NaN            1807.0
# nominate_dim1                                 NaN            -0.165
# nominate_dim2                                 NaN            -0.373
# nominate_log_likelihood                       NaN         -28.55029
# nominate_geo_mean_probability                 NaN             0.758
# nominate_number_of_votes                      NaN             103.0
# nominate_number_of_errors                     NaN              12.0
# conditional                                   NaN               NaN
# nokken_poole_dim1                             NaN            -0.429
# nokken_poole_dim2                             NaN            -0.817
#
#                                             2
# congress                                    1
# chamber                                 House
# icpsr                                    4854
# state_icpsr                                44
# district_code                             1.0
# state_abbrev                               GA
# party_code                               4000
# occupancy                                 0.0
# last_means                                1.0
# bioname                        JACKSON, James
# bioguide_id                           J000017
# born                                   1757.0
# died                                   1806.0
# nominate_dim1                           -0.32
# nominate_dim2                          -0.181
# nominate_log_likelihood             -24.89986
# nominate_geo_mean_probability           0.776
# nominate_number_of_votes                 98.0
# nominate_number_of_errors                 9.0
# conditional                               NaN
# nokken_poole_dim1                      -0.559
# nokken_poole_dim2                      -0.052

# %%
ideology.describe()
# Out:
#            congress         icpsr   state_icpsr  district_code    party_code  \
# count  50485.000000  50485.000000  50485.000000   50485.000000  50485.000000
# mean      69.769278   9789.065267     33.720848       9.292324    226.161137
# std       30.678284  10197.040287     20.550665      16.310987    656.447344
# min        1.000000      1.000000      1.000000       0.000000      1.000000
# 25%       47.000000   3671.000000     14.000000       1.000000    100.000000
# 50%       73.000000   7439.000000     33.000000       5.000000    100.000000
# 75%       95.000000  12038.000000     49.000000      10.000000    200.000000
# max      118.000000  99999.000000     99.000000      99.000000   8888.000000
#
#           occupancy    last_means          born          died  nominate_dim1  \
# count  48213.000000  48213.000000  50214.000000  40705.000000   50264.000000
# mean       0.131583      1.225022   1875.624467   1930.994202       0.006415
# std        0.526830      0.671845     58.114890     55.385986       0.375653
# min        0.000000      0.000000   1721.000000   1790.000000      -1.000000
# 25%        0.000000      1.000000   1832.000000   1891.000000      -0.330000
# 50%        0.000000      1.000000   1878.000000   1934.000000      -0.041000
# 75%        0.000000      1.000000   1926.000000   1975.000000       0.349000
# max        7.000000      7.000000   1997.000000   2023.000000       1.000000
#
#        nominate_dim2  nominate_log_likelihood  nominate_geo_mean_probability  \
# count   50264.000000             49255.000000                   49255.000000
# mean        0.015546              -101.942486                       0.753703
# std         0.463398                93.700539                       0.098882
# min        -1.000000             -1135.015230                       0.160000
# 25%        -0.300000              -140.691140                       0.689000
# 50%        -0.009000               -69.607040                       0.756000
# 75%         0.308000               -36.046405                       0.822000
# max         1.000000                -0.000050                       0.999950
#
#        nominate_number_of_votes  nominate_number_of_errors  conditional  \
# count              49255.000000               49255.000000          0.0
# mean                 384.777119                  45.964146          NaN
# std                  325.925811                  43.598731          NaN
# min                    1.000000                   0.000000          NaN
# 25%                  131.000000                  15.000000          NaN
# 50%                  246.000000                  31.000000          NaN
# 75%                  589.000000                  63.000000          NaN
# max                 1434.000000                 498.000000          NaN
#
#        nokken_poole_dim1  nokken_poole_dim2
# count       50019.000000       50019.000000
# mean            0.005966           0.013630
# std             0.393062           0.486987
# min            -1.000000          -1.000000
# 25%            -0.339000          -0.327000
# 50%            -0.036000           0.000000
# 75%             0.354000           0.343000
# max             1.000000           1.000000

# %%
ideology.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50485 entries, 0 to 50484
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   congress                       50485 non-null  int64
#  1   chamber                        50485 non-null  object
#  2   icpsr                          50485 non-null  int64
#  3   state_icpsr                    50485 non-null  int64
#  4   district_code                  50485 non-null  float64
#  5   state_abbrev                   50485 non-null  object
#  6   party_code                     50485 non-null  int64
#  7   occupancy                      48213 non-null  float64
#  8   last_means                     48213 non-null  float64
#  9   bioname                        50485 non-null  object
#  10  bioguide_id                    50418 non-null  object
#  11  born                           50214 non-null  float64
#  12  died                           40705 non-null  float64
#  13  nominate_dim1                  50264 non-null  float64
#  14  nominate_dim2                  50264 non-null  float64
#  15  nominate_log_likelihood        49255 non-null  float64
#  16  nominate_geo_mean_probability  49255 non-null  float64
#  17  nominate_number_of_votes       49255 non-null  float64
#  18  nominate_number_of_errors      49255 non-null  float64
#  19  conditional                    0 non-null      float64
#  20  nokken_poole_dim1              50019 non-null  float64
#  21  nokken_poole_dim2              50019 non-null  float64
# dtypes: float64(14), int64(4), object(4)
# memory usage: 8.5+ MB

# %%
profile = ProfileReport(ideology,title="congressional ideology data",
                        html={"style":{"full_width":True}},
                       minimal = True)
profile.to_file("congress_ideology.html")
# Out:
# Summarize dataset: 100%|██████████| 28/28 [00:00<00:00, 49.84it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:05<00:00,  5.52s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.24it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 47.72it/s]

# %%
url = "https://voteview.com/static/data/out/rollcalls/HSall_rollcalls.csv"
votes = pd.read_csv(url)
# Out:
# /tmp/ipykernel_21/2285166436.py:2: DtypeWarning: Columns (14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   votes = pd.read_csv(url)

# %%
profile = ProfileReport(votes,title="Congressional Vote Metadata",
                        html={"style":{"full_width":True}},
                       minimal = True)
profile.to_file("congress_votes.html")
# Out:
# Summarize dataset: 100%|██████████| 24/24 [00:05<00:00,  4.26it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:06<00:00,  6.16s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.14it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 30.51it/s]

# %%
url = "https://voteview.com/static/data/out/votes/HSall_votes.csv"
memberVotes = pd.read_csv(url)

# %%
profile = ProfileReport(memberVotes,title="Member Vote Data",
                        html={"style":{"full_width":True}},
                       minimal = True)
profile.to_file("member_votes.html")
# Out:
# Summarize dataset: 100%|██████████| 12/12 [00:17<00:00,  1.44s/it, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.67s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00, 11.01it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 87.69it/s]

# %%
election = pd.read_csv("1976-2022-house.tab" , delimiter = '\t')

# %%
election
# Out:
#        year    state state_po  state_fips  state_cen  state_ic    office  \
# 0      1976  ALABAMA       AL           1         63        41  US HOUSE
# 1      1976  ALABAMA       AL           1         63        41  US HOUSE
# 2      1976  ALABAMA       AL           1         63        41  US HOUSE
# 3      1976  ALABAMA       AL           1         63        41  US HOUSE
# 4      1976  ALABAMA       AL           1         63        41  US HOUSE
# ...     ...      ...      ...         ...        ...       ...       ...
# 32447  2022  WYOMING       WY          56         83        68  US HOUSE
# 32448  2022  WYOMING       WY          56         83        68  US HOUSE
# 32449  2022  WYOMING       WY          56         83        68  US HOUSE
# 32450  2022  WYOMING       WY          56         83        68  US HOUSE
# 32451  2022  WYOMING       WY          56         83        68  US HOUSE
#
#        district stage runoff  special                     candidate  \
# 0             1   GEN  False    False                BILL DAVENPORT
# 1             1   GEN  False    False                  JACK EDWARDS
# 2             1   GEN  False    False                       WRITEIN
# 3             2   GEN  False    False               J CAROLE KEAHEY
# 4             2   GEN  False    False  WILLIAM L \BILL\" DICKINSON"
# ...         ...   ...    ...      ...                           ...
# 32447         0   GEN  False    False              RICHARD BRUBAKER
# 32448         0   GEN  False    False            MARISSA JOY SELVIG
# 32449         0   GEN  False    False                       WRITEIN
# 32450         0   GEN  False    False                    UNDERVOTES
# 32451         0   GEN  False    False                     OVERVOTES
#
#               party  writein   mode  candidatevotes  totalvotes  unofficial  \
# 0          DEMOCRAT    False  TOTAL           58906      157170       False
# 1        REPUBLICAN    False  TOTAL           98257      157170       False
# 2               NaN     True  TOTAL               7      157170       False
# 3          DEMOCRAT    False  TOTAL           66288      156362       False
# 4        REPUBLICAN    False  TOTAL           90069      156362       False
# ...             ...      ...    ...             ...         ...         ...
# 32447   LIBERTARIAN    False  TOTAL            5420      198198       False
# 32448  CONSTITUTION    False  TOTAL            4505      198198       False
# 32449           NaN     True  TOTAL            4521      198198       False
# 32450           NaN    False  TOTAL            3660      198198       False
# 32451           NaN    False  TOTAL             636      198198       False
#
#         version  fusion_ticket
# 0      20230706          False
# 1      20230706          False
# 2      20230706          False
# 3      20230706          False
# 4      20230706          False
# ...         ...            ...
# 32447  20230706          False
# 32448  20230706          False
# 32449  20230706          False
# 32450  20230706          False
# 32451  20230706          False
#
# [32452 rows x 20 columns]

# %%
profile = ProfileReport(election,title="House of Representative Election Data",
                        html={"style":{"full_width":True}},
                       minimal = True)
profile.to_file("elections_house.html")
# Out:
# Summarize dataset: 100%|██████████| 26/26 [00:01<00:00, 17.95it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:05<00:00,  5.09s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.94it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 40.90it/s]
