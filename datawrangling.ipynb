# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Bring the voteview data and filter to the 118th congress

# %%
ideology = pd.read_csv("https://voteview.com/static/data/out/members/HS118_members.csv")

# %%
ideology["chamber"].value_counts()
# Out:
# chamber
# House     442
# Senate    101
# Name: count, dtype: int64

# %%
ideology[["bioname",'chamber','party_code','district_code','state_abbrev','nominate_dim1']]\
.sort_values("nominate_dim1",ascending=True, ignore_index = True)


# ['bioname'].sort_values['nominate_dim1']
# Out:
#                                bioname chamber  party_code  district_code  \
# 0                       GARCIA, Sylvia   House         100             29
# 1                    WARREN, Elizabeth  Senate         100              0
# 2                         LEE, Barbara   House         100             12
# 3                       WATERS, Maxine   House         100             43
# 4                         CASTEN, Sean   House         100              6
# ..                                 ...     ...         ...            ...
# 538                    MCCORMICK, Rich   House         200              6
# 539                          LEE, Mike  Senate         200              0
# 540                         PAUL, Rand  Senate         200              0
# 541  TUBERVILLE, Thomas Hawley (Tommy)  Senate         200              0
# 542              SCHMITT, Eric Stephen  Senate         200              0
#
#     state_abbrev  nominate_dim1
# 0             TX         -0.792
# 1             MA         -0.751
# 2             CA         -0.677
# 3             CA         -0.656
# 4             IL         -0.652
# ..           ...            ...
# 538           GA          0.870
# 539           UT          0.891
# 540           KY          0.891
# 541           AL          0.936
# 542           MO          0.965
#
# [543 rows x 6 columns]

# %%
replace_map = {100:'Democrat',200:'Republican',328:"independent"}

ideology['party_code'] = ideology['party_code'].replace(replace_map)
ideology["party_code"].value_counts()
# Out:
# party_code
# Republican     274
# Democrat       266
# independent      3
# Name: count, dtype: int64

# %%
ideology.query("party_code == 'independent'")[['bioname','chamber','state_abbrev','nominate_dim1']]
# Out:
#                       bioname chamber state_abbrev  nominate_dim1
# 447           SINEMA, Kyrsten  Senate           AZ         -0.246
# 479  KING, Angus Stanley, Jr.  Senate           ME         -0.162
# 532          SANDERS, Bernard  Senate           VT         -0.539

# %%
ideology.query("state_abbrev == 'VA' & chamber == 'House'")[['district_code','party_code','bioname']]
# Out:
#      district_code  party_code                      bioname
# 410              1  Republican           WITTMAN, Robert J.
# 411             11    Democrat  CONNOLLY, Gerald E. (Gerry)
# 412              9  Republican          GRIFFITH, H. Morgan
# 413              8    Democrat   BEYER, Donald Sternoff Jr.
# 414              6  Republican              CLINE, Benjamin
# 415              7    Democrat          SPANBERGER, Abigail
# 416             10    Democrat             WEXTON, Jennifer
# 417              5  Republican                    GOOD, Bob
# 418              2  Republican            KIGGANS, Jennifer
# 419              4    Democrat          MCCLELLAN, Jennifer
# 420              3    Democrat             SCOTT, Robert C.

# %%
votes = pd.read_csv("https://voteview.com/static/data/out/votes/HS118_votes.csv")

# %%
votes
# Out:
#         congress chamber  rollnumber  icpsr  cast_code   prob
# 0            118   House           1  14854          6  100.0
# 1            118   House           1  14863          6   98.1
# 2            118   House           1  14873          1  100.0
# 3            118   House           1  15029          1  100.0
# 4            118   House           1  15433          1  100.0
# ...          ...     ...         ...    ...        ...    ...
# 323858       118  Senate         313  42304          1   90.7
# 323859       118  Senate         313  42305          1   92.6
# 323860       118  Senate         313  49308          1   88.6
# 323861       118  Senate         313  49703          1   98.6
# 323862       118  Senate         313  91300          1  100.0
#
# [323863 rows x 6 columns]

# %%
# first do the merge in a way to checks for problems
ideology_votes = pd.merge(votes,ideology,on = 'icpsr', how = 'outer', validate = 'many_to_one',indicator = 'matched')

# %%
ideology_votes = pd.merge(votes,ideology,on = 'icpsr', how = 'inner')

# %%
ideology_votes
# Out:
#         congress_x chamber_x  rollnumber  icpsr  cast_code   prob  congress_y  \
# 0              118     House           1  14854          6  100.0         118
# 1              118     House           2  14854          6  100.0         118
# 2              118     House           3  14854          6  100.0         118
# 3              118     House           4  14854          6  100.0         118
# 4              118     House           5  14854          6  100.0         118
# ...            ...       ...         ...    ...        ...    ...         ...
# 323858         118    Senate         309  42305          1  100.0         118
# 323859         118    Senate         310  42305          6  100.0         118
# 323860         118    Senate         311  42305          6  100.0         118
# 323861         118    Senate         312  42305          1   96.9         118
# 323862         118    Senate         313  42305          1   92.6         118
#
#        chamber_y  state_icpsr  district_code  ... died nominate_dim1  \
# 0          House           51              5  ...  NaN         0.334
# 1          House           51              5  ...  NaN         0.334
# 2          House           51              5  ...  NaN         0.334
# 3          House           51              5  ...  NaN         0.334
# 4          House           51              5  ...  NaN         0.334
# ...          ...          ...            ...  ...  ...           ...
# 323858    Senate           71              0  ...  NaN        -0.470
# 323859    Senate           71              0  ...  NaN        -0.470
# 323860    Senate           71              0  ...  NaN        -0.470
# 323861    Senate           71              0  ...  NaN        -0.470
# 323862    Senate           71              0  ...  NaN        -0.470
#
#         nominate_dim2  nominate_log_likelihood nominate_geo_mean_probability  \
# 0               0.142                -91.32590                       0.86116
# 1               0.142                -91.32590                       0.86116
# 2               0.142                -91.32590                       0.86116
# 3               0.142                -91.32590                       0.86116
# 4               0.142                -91.32590                       0.86116
# ...               ...                      ...                           ...
# 323858         -0.085                 -0.51644                       0.98972
# 323859         -0.085                 -0.51644                       0.98972
# 323860         -0.085                 -0.51644                       0.98972
# 323861         -0.085                 -0.51644                       0.98972
# 323862         -0.085                 -0.51644                       0.98972
#
#        nominate_number_of_votes  nominate_number_of_errors  conditional  \
# 0                           611                         30          NaN
# 1                           611                         30          NaN
# 2                           611                         30          NaN
# 3                           611                         30          NaN
# 4                           611                         30          NaN
# ...                         ...                        ...          ...
# 323858                       50                          0          NaN
# 323859                       50                          0          NaN
# 323860                       50                          0          NaN
# 323861                       50                          0          NaN
# 323862                       50                          0          NaN
#
#         nokken_poole_dim1  nokken_poole_dim2
# 0                   0.360              0.742
# 1                   0.360              0.742
# 2                   0.360              0.742
# 3                   0.360              0.742
# 4                   0.360              0.742
# ...                   ...                ...
# 323858             -0.527             -0.138
# 323859             -0.527             -0.138
# 323860             -0.527             -0.138
# 323861             -0.527             -0.138
# 323862             -0.527             -0.138
#
# [323863 rows x 27 columns]
