# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## original data

# %%
nba = pd.read_csv("nba.csv", low_memory = False)
pd.set_option("display.max_column", 30)
pd.set_option("display.max_row", 50)
nba.head(6).T
# Out:
#                                     0             1             2  \
# Unnamed: 0                          0             1             2
# game_id                  202202170BRK  202202170BRK  202202170BRK
# game_date                  2022-02-17    2022-02-17    2022-02-17
# OT                                  0             0             0
# H_A                                 A             A             A
# ...                               ...           ...           ...
# SG%                              36.0           0.0          32.0
# SF%                              60.0           4.0          67.0
# PF%                               4.0          85.0           0.0
# C%                                0.0          11.0           0.0
# active_position_minutes     46.253586      52.15259     47.021807
#
#                                     3             4             5
# Unnamed: 0                          3             4             5
# game_id                  202202170BRK  202202170BRK  202202170BRK
# game_date                  2022-02-17    2022-02-17    2022-02-17
# OT                                  0             0             0
# H_A                                 A             A             A
# ...                               ...           ...           ...
# SG%                              10.0           0.0           7.0
# SF%                               0.0           0.0          62.0
# PF%                               0.0           0.0          31.0
# C%                                0.0         100.0           0.0
# active_position_minutes     27.603314     36.472537     54.944529
#
# [82 rows x 6 columns]

# %%
## first normal form 

nba = nba.drop(["Inactives"],axis = 1)
nba.head(3).T
# Out:
#                                     0             1             2
# Unnamed: 0                          0             1             2
# game_id                  202202170BRK  202202170BRK  202202170BRK
# game_date                  2022-02-17    2022-02-17    2022-02-17
# OT                                  0             0             0
# H_A                                 A             A             A
# ...                               ...           ...           ...
# SG%                              36.0           0.0          32.0
# SF%                              60.0           4.0          67.0
# PF%                               4.0          85.0           0.0
# C%                                0.0          11.0           0.0
# active_position_minutes     46.253586      52.15259     47.021807
#
# [81 rows x 3 columns]

# %% [markdown]
# ## Second Normal Form

# %%
# second normal form 
# Only have one column for the primary keep it's kinda cheating
players = nba[["player_id","player"]].drop_duplicates()

# %%
games = nba[["game_id","game_date","OT","season"]].drop_duplicates()

# %%
# third normal form 

nba = nba.drop(["game_date","OT","season"],axis = 1)

# %%
nba.T
# Out:
#                                0             1             2       \
# Unnamed: 0                          0             1             2
# game_id                  202202170BRK  202202170BRK  202202170BRK
# game_date                  2022-02-17    2022-02-17    2022-02-17
# OT                                  0             0             0
# H_A                                 A             A             A
# ...                               ...           ...           ...
# SG%                              36.0           0.0          32.0
# SF%                              60.0           4.0          67.0
# PF%                               4.0          85.0           0.0
# C%                                0.0          11.0           0.0
# active_position_minutes     46.253586      52.15259     47.021807
#
#                                3             4             5       \
# Unnamed: 0                          3             4             5
# game_id                  202202170BRK  202202170BRK  202202170BRK
# game_date                  2022-02-17    2022-02-17    2022-02-17
# OT                                  0             0             0
# H_A                                 A             A             A
# ...                               ...           ...           ...
# SG%                              10.0           0.0           7.0
# SF%                               0.0           0.0          62.0
# PF%                               0.0           0.0          31.0
# C%                                0.0         100.0           0.0
# active_position_minutes     27.603314     36.472537     54.944529
#
#                                6             7             8       \
# Unnamed: 0                          6             7             8
# game_id                  202202170BRK  202202170BRK  202202170BRK
# game_date                  2022-02-17    2022-02-17    2022-02-17
# OT                                  0             0             0
# H_A                                 A             A             A
# ...                               ...           ...           ...
# SG%                               0.0           0.0           0.0
# SF%                               0.0          33.0          16.0
# PF%                               0.0          57.0          70.0
# C%                                0.0          10.0          14.0
# active_position_minutes      28.08385     53.836511     52.255931
#
#                                9             10            11      \
# Unnamed: 0                          9            10            11
# game_id                  202202170BRK  202202170BRK  202202170BRK
# game_date                  2022-02-17    2022-02-17    2022-02-17
# OT                                  0             0             0
# H_A                                 A             A             A
# ...                               ...           ...           ...
# SG%                               0.0          38.0           0.0
# SF%                               0.0           0.0           0.0
# PF%                               0.0           0.0           0.0
# C%                              100.0           0.0         100.0
# active_position_minutes     36.472537     26.257811     36.472537
#
#                                12            13            14      ...  \
# Unnamed: 0                         12            13            14  ...
# game_id                  202202170BRK  202202170BRK  202202170BRK  ...
# game_date                  2022-02-17    2022-02-17    2022-02-17  ...
# OT                                  0             0             0  ...
# H_A                                 A             H             H  ...
# ...                               ...           ...           ...  ...
# SG%                               0.0          31.0          82.0  ...
# SF%                              11.0          58.0           8.0  ...
# PF%                              47.0          11.0           0.0  ...
# C%                               42.0           0.0           0.0  ...
# active_position_minutes     47.128051      43.39704     50.406013  ...
#
#                                112108        112109        112110  \
# Unnamed: 0                     112108        112109        112110
# game_id                  202003030DEN  202003030DEN  202003030DEN
# game_date                  2020-03-03    2020-03-03    2020-03-03
# OT                                  0             0             0
# H_A                                 A             A             A
# ...                               ...           ...           ...
# SG%                              45.0           0.0          44.0
# SF%                              43.0           0.0          48.0
# PF%                               7.0           9.0           8.0
# C%                                0.0          91.0           0.0
# active_position_minutes           NaN           NaN           NaN
#
#                                112111        112112        112113  \
# Unnamed: 0                     112111        112112        112113
# game_id                  202003030DEN  202003070GSW  202003070GSW
# game_date                  2020-03-03    2020-03-07    2020-03-07
# OT                                  0             0             0
# H_A                                 A             H             H
# ...                               ...           ...           ...
# SG%                              19.0           0.0           0.0
# SF%                               0.0           0.0          14.0
# PF%                               0.0          35.0          76.0
# C%                                0.0          65.0          10.0
# active_position_minutes           NaN      49.80189     51.395891
#
#                                112114        112115        112116  \
# Unnamed: 0                     112114        112115        112116
# game_id                  202003070GSW  202003070GSW  202003070GSW
# game_date                  2020-03-07    2020-03-07    2020-03-07
# OT                                  0             0             0
# H_A                                 H             H             H
# ...                               ...           ...           ...
# SG%                              59.0           0.0          65.0
# SF%                               2.0           0.0          16.0
# PF%                               0.0          36.0           0.0
# C%                                0.0          64.0           0.0
# active_position_minutes     53.414398     49.808477     56.787002
#
#                                112117        112118        112119  \
# Unnamed: 0                     112117        112118        112119
# game_id                  202003070GSW  202003070GSW  202003070GSW
# game_date                  2020-03-07    2020-03-07    2020-03-07
# OT                                  0             0             0
# H_A                                 H             H             H
# ...                               ...           ...           ...
# SG%                               0.0           2.0          45.0
# SF%                               0.0          77.0          43.0
# PF%                               0.0          21.0           7.0
# C%                                0.0           0.0           0.0
# active_position_minutes     42.573689     57.207786     58.202391
#
#                                112120        112121        112122
# Unnamed: 0                     112120        112121        112122
# game_id                  202003070GSW  202003070GSW  202003070GSW
# game_date                  2020-03-07    2020-03-07    2020-03-07
# OT                                  0             0             0
# H_A                                 H             H             H
# ...                               ...           ...           ...
# SG%                               0.0          44.0          19.0
# SF%                               0.0          48.0           0.0
# PF%                               9.0           8.0           0.0
# C%                               91.0           0.0           0.0
# active_position_minutes      49.63064     58.923515     45.958787
#
# [82 rows x 112123 columns]

# %%
nba.columns
# Out:
# Index(['Unnamed: 0', 'game_id', 'game_date', 'OT', 'H_A', 'Team_Abbrev',
#        'Team_Score', 'Team_pace', 'Team_efg_pct', 'Team_tov_pct',
#        'Team_orb_pct', 'Team_ft_rate', 'Team_off_rtg', 'Inactives',
#        'Opponent_Abbrev', 'Opponent_Score', 'Opponent_pace',
#        'Opponent_efg_pct', 'Opponent_tov_pct', 'Opponent_orb_pct',
#        'Opponent_ft_rate', 'Opponent_off_rtg', 'player', 'player_id',
#        'starter', 'mp', 'fg', 'fga', 'fg_pct', 'fg3', 'fg3a', 'fg3_pct', 'ft',
#        'fta', 'ft_pct', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf',
#        'pts', 'plus_minus', 'did_not_play', 'is_inactive', 'ts_pct', 'efg_pct',
#        'fg3a_per_fga_pct', 'fta_per_fga_pct', 'orb_pct', 'drb_pct', 'trb_pct',
#        'ast_pct', 'stl_pct', 'blk_pct', 'tov_pct', 'usg_pct', 'off_rtg',
#        'def_rtg', 'bpm', 'season', 'minutes', 'double_double', 'triple_double',
#        'DKP', 'FDP', 'SDP', 'DKP_per_minute', 'FDP_per_minute',
#        'SDP_per_minute', 'pf_per_minute', 'ts',
#        'last_60_minutes_per_game_starting', 'last_60_minutes_per_game_bench',
#        'PG%', 'SG%', 'SF%', 'PF%', 'C%', 'active_position_minutes'],
#       dtype='object')

# %% [markdown]
# ## Third Normal Form

# %%
team_game = nba[["game_id","Team_Abbrev",'H_A','Team_Abbrev',
       'Team_Score', 'Team_pace', 'Team_efg_pct', 'Team_tov_pct',
       'Team_orb_pct', 'Team_ft_rate', 'Team_off_rtg',"Opponent_Abbrev"]].drop_duplicates()

# %%
team_game
# Out:
#              game_id Team_Abbrev H_A Team_Abbrev  Team_Score  Team_pace  \
# 0       202202170BRK         WAS   A         WAS         117       94.5
# 13      202202170BRK         BRK   H         BRK         103       94.5
# 26      202202170CHO         MIA   A         MIA         111       88.8
# 37      202202170CHO         CHO   H         CHO         107       88.8
# 48      202202170LAC         HOU   A         HOU         111      103.7
# ...              ...         ...  ..         ...         ...        ...
# 112068  202002270GSW         GSW   H         GSW          86      104.8
# 112079  202002290PHO         GSW   A         GSW         115       98.6
# 112090  202003010GSW         GSW   H         GSW         110      100.2
# 112101  202003030DEN         GSW   A         GSW         116       94.4
# 112112  202003070GSW         GSW   H         GSW         118       90.9
#
#         Team_efg_pct  Team_tov_pct  Team_orb_pct  Team_ft_rate  Team_off_rtg  \
# 0              0.627          13.5          22.9         0.157         123.8
# 13             0.483          13.1          33.3         0.191         109.0
# 26             0.471          11.1          26.8         0.147         103.4
# 37             0.453          13.6          28.1         0.221          99.7
# 48             0.533          15.3          24.0         0.154         107.1
# ...              ...           ...           ...           ...           ...
# 112068         0.481          23.6          12.2         0.113          82.1
# 112079         0.523           9.0          28.9         0.276         116.6
# 112090         0.522          17.4          38.3         0.191         109.8
# 112101         0.622          10.7          12.8         0.171         122.9
# 112112         0.606           7.0          18.9         0.263         129.9
#
#        Opponent_Abbrev
# 0                  BRK
# 13                 WAS
# 26                 CHO
# 37                 MIA
# 48                 LAC
# ...                ...
# 112068             LAL
# 112079             PHO
# 112090             WAS
# 112101             DEN
# 112112             PHI
#
# [6394 rows x 12 columns]

# %%
player_game = nba.drop(["game_id","Team_Abbrev",'H_A','Team_Abbrev',
       'Team_Score', 'Team_pace', 'Team_efg_pct', 'Team_tov_pct',
       'Team_orb_pct', 'Team_ft_rate', 'Team_off_rtg',"Opponent_Abbrev","Unnamed: 0"],axis = 1)

# %%
player_game
# Out:
#          game_date  OT                                          Inactives  \
# 0       2022-02-17   0       Joel Ayayi, Bradley Beal, Kristaps Porzingis
# 1       2022-02-17   0       Joel Ayayi, Bradley Beal, Kristaps Porzingis
# 2       2022-02-17   0       Joel Ayayi, Bradley Beal, Kristaps Porzingis
# 3       2022-02-17   0       Joel Ayayi, Bradley Beal, Kristaps Porzingis
# 4       2022-02-17   0       Joel Ayayi, Bradley Beal, Kristaps Porzingis
# ...            ...  ..                                                ...
# 112118  2020-03-07   0  Stephen Curry, Draymond Green, Alen Smailagic,...
# 112119  2020-03-07   0  Stephen Curry, Draymond Green, Alen Smailagic,...
# 112120  2020-03-07   0  Stephen Curry, Draymond Green, Alen Smailagic,...
# 112121  2020-03-07   0  Stephen Curry, Draymond Green, Alen Smailagic,...
# 112122  2020-03-07   0  Stephen Curry, Draymond Green, Alen Smailagic,...
#
#         Opponent_Score  Opponent_pace  Opponent_efg_pct  Opponent_tov_pct  \
# 0                  103           94.5             0.483              13.1
# 1                  103           94.5             0.483              13.1
# 2                  103           94.5             0.483              13.1
# 3                  103           94.5             0.483              13.1
# 4                  103           94.5             0.483              13.1
# ...                ...            ...               ...               ...
# 112118             114           90.9             0.565              10.5
# 112119             114           90.9             0.565              10.5
# 112120             114           90.9             0.565              10.5
# 112121             114           90.9             0.565              10.5
# 112122             114           90.9             0.565              10.5
#
#         Opponent_orb_pct  Opponent_ft_rate  Opponent_off_rtg  \
# 0                   33.3             0.191             109.0
# 1                   33.3             0.191             109.0
# 2                   33.3             0.191             109.0
# 3                   33.3             0.191             109.0
# 4                   33.3             0.191             109.0
# ...                  ...               ...               ...
# 112118              28.2             0.226             125.5
# 112119              28.2             0.226             125.5
# 112120              28.2             0.226             125.5
# 112121              28.2             0.226             125.5
# 112122              28.2             0.226             125.5
#
#                           player  player_id  starter        mp  fg  ...   FDP  \
# 0                  Corey Kispert  kispeco01        1     32:30   6  ...  22.7
# 1                     Kyle Kuzma  kuzmaky01        1     30:16   2  ...  16.9
# 2       Kentavious Caldwell-Pope  caldwke01        1     25:26   3  ...  18.0
# 3                      Raul Neto   netora01        1     20:40   5  ...  24.9
# 4                  Thomas Bryant  bryanth01        1     14:04   5  ...  27.0
# ...                          ...        ...      ...       ...  ..  ...   ...
# 112118            Andrew Wiggins  wiggian01        1  37:04:00   3  ...  25.8
# 112119     Juan Toscano-Anderson  toscaju01        1  27:43:00   3  ...  16.2
# 112120             Dragan Bender  bendedr01        0     13:15   4  ...  15.1
# 112121             Mychal Mulder  muldemy01        1  31:48:00   5  ...  23.7
# 112122            Chasson Randle  randlch01        0     13:36   0  ...   8.7
#
#           SDP     DKP_per_minute     FDP_per_minute     SDP_per_minute  \
# 0       24.75  0.730769230769231  0.698461538461538  0.761538461538461
# 1       17.25  0.652533039647577  0.558370044052863  0.569933920704846
# 2       18.75  0.717562254259502  0.707732634338139  0.737221494102228
# 3       25.50   1.13709677419355   1.20483870967742   1.23387096774194
# 4       27.25   1.79502369668246   1.91943127962085   1.93720379146919
# ...       ...                ...                ...                ...
# 112118  26.00        0.660971223        0.696043165        0.701438849
# 112119  16.50        0.595309681        0.584485869        0.595309681
# 112120  16.25        1.226415094        1.139622642        1.226415094
# 112121  25.25        0.794025157        0.745283019        0.794025157
# 112122   8.75        0.569852941        0.639705882        0.643382353
#
#         pf_per_minute     ts  last_60_minutes_per_game_starting  \
# 0            0.061538   9.00                          31.716667
# 1            0.099119   7.44                          34.324000
# 2            0.000000   7.00                          29.820290
# 3            0.048387   7.88                          29.920833
# 4            0.000000   6.88                          20.095833
# ...               ...    ...                                ...
# 112118       0.107914  13.08                          33.110667
# 112119       0.036079   6.00                          25.470833
# 112120       0.150943   4.00                          24.083333
# 112121       0.094340  12.64                          34.783333
# 112122       0.000000   2.76                          10.415645
#
#         last_60_minutes_per_game_bench   PG%   SG%   SF%   PF%     C%  \
# 0                            22.017778   1.0  36.0  60.0   4.0    0.0
# 1                            18.475954   0.0   0.0   4.0  85.0   11.0
# 2                            16.051693   0.0  32.0  67.0   0.0    0.0
# 3                            14.603922  90.0  10.0   0.0   0.0    0.0
# 4                            14.538095   0.0   0.0   0.0   0.0  100.0
# ...                                ...   ...   ...   ...   ...    ...
# 112118                       19.232562   0.0   2.0  77.0  21.0    0.0
# 112119                       20.228571   5.0  45.0  43.0   7.0    0.0
# 112120                       13.228788   0.0   0.0   0.0   9.0   91.0
# 112121                       27.691667   0.0  44.0  48.0   8.0    0.0
# 112122                        6.050000  81.0  19.0   0.0   0.0    0.0
#
#         active_position_minutes
# 0                     46.253586
# 1                     52.152590
# 2                     47.021807
# 3                     27.603314
# 4                     36.472537
# ...                         ...
# 112118                57.207786
# 112119                58.202391
# 112120                49.630640
# 112121                58.923515
# 112122                45.958787
#
# [112123 rows x 70 columns]

# %%
team_game
# Out:
#              game_id Team_Abbrev H_A Team_Abbrev  Team_Score  Team_pace  \
# 0       202202170BRK         WAS   A         WAS         117       94.5
# 13      202202170BRK         BRK   H         BRK         103       94.5
# 26      202202170CHO         MIA   A         MIA         111       88.8
# 37      202202170CHO         CHO   H         CHO         107       88.8
# 48      202202170LAC         HOU   A         HOU         111      103.7
# ...              ...         ...  ..         ...         ...        ...
# 112068  202002270GSW         GSW   H         GSW          86      104.8
# 112079  202002290PHO         GSW   A         GSW         115       98.6
# 112090  202003010GSW         GSW   H         GSW         110      100.2
# 112101  202003030DEN         GSW   A         GSW         116       94.4
# 112112  202003070GSW         GSW   H         GSW         118       90.9
#
#         Team_efg_pct  Team_tov_pct  Team_orb_pct  Team_ft_rate  Team_off_rtg  \
# 0              0.627          13.5          22.9         0.157         123.8
# 13             0.483          13.1          33.3         0.191         109.0
# 26             0.471          11.1          26.8         0.147         103.4
# 37             0.453          13.6          28.1         0.221          99.7
# 48             0.533          15.3          24.0         0.154         107.1
# ...              ...           ...           ...           ...           ...
# 112068         0.481          23.6          12.2         0.113          82.1
# 112079         0.523           9.0          28.9         0.276         116.6
# 112090         0.522          17.4          38.3         0.191         109.8
# 112101         0.622          10.7          12.8         0.171         122.9
# 112112         0.606           7.0          18.9         0.263         129.9
#
#        Opponent_Abbrev
# 0                  BRK
# 13                 WAS
# 26                 CHO
# 37                 MIA
# 48                 LAC
# ...                ...
# 112068             LAL
# 112079             PHO
# 112090             WAS
# 112101             DEN
# 112112             PHI
#
# [6394 rows x 12 columns]

# %%
player_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112123 entries, 0 to 112122
# Data columns (total 70 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   game_date                          112123 non-null  object
#  1   OT                                 112123 non-null  int64
#  2   Inactives                          112010 non-null  object
#  3   Opponent_Score                     112123 non-null  int64
#  4   Opponent_pace                      112123 non-null  float64
#  5   Opponent_efg_pct                   112123 non-null  float64
#  6   Opponent_tov_pct                   112123 non-null  float64
#  7   Opponent_orb_pct                   112123 non-null  float64
#  8   Opponent_ft_rate                   112123 non-null  float64
#  9   Opponent_off_rtg                   112123 non-null  float64
#  10  player                             112123 non-null  object
#  11  player_id                          112123 non-null  object
#  12  starter                            112123 non-null  int64
#  13  mp                                 112123 non-null  object
#  14  fg                                 112123 non-null  int64
#  15  fga                                112123 non-null  int64
#  16  fg_pct                             112123 non-null  float64
#  17  fg3                                112123 non-null  int64
#  18  fg3a                               112123 non-null  int64
#  19  fg3_pct                            112123 non-null  float64
#  20  ft                                 112123 non-null  int64
#  21  fta                                112123 non-null  int64
#  22  ft_pct                             112123 non-null  float64
#  23  orb                                112123 non-null  int64
#  24  drb                                112123 non-null  int64
#  25  trb                                112123 non-null  int64
#  26  ast                                112123 non-null  int64
#  27  stl                                112123 non-null  int64
#  28  blk                                112123 non-null  int64
#  29  tov                                112123 non-null  int64
#  30  pf                                 112123 non-null  int64
#  31  pts                                112123 non-null  int64
#  32  plus_minus                         112123 non-null  int64
#  33  did_not_play                       112123 non-null  int64
#  34  is_inactive                        112123 non-null  int64
#  35  ts_pct                             112123 non-null  float64
#  36  efg_pct                            112123 non-null  float64
#  37  fg3a_per_fga_pct                   112123 non-null  float64
#  38  fta_per_fga_pct                    112123 non-null  float64
#  39  orb_pct                            112123 non-null  float64
#  40  drb_pct                            112123 non-null  float64
#  41  trb_pct                            112123 non-null  float64
#  42  ast_pct                            112123 non-null  float64
#  43  stl_pct                            112123 non-null  float64
#  44  blk_pct                            112123 non-null  float64
#  45  tov_pct                            112123 non-null  float64
#  46  usg_pct                            112123 non-null  float64
#  47  off_rtg                            112123 non-null  int64
#  48  def_rtg                            112123 non-null  int64
#  49  bpm                                112123 non-null  float64
#  50  season                             112123 non-null  int64
#  51  minutes                            112123 non-null  float64
#  52  double_double                      112123 non-null  int64
#  53  triple_double                      112123 non-null  int64
#  54  DKP                                112123 non-null  float64
#  55  FDP                                112123 non-null  float64
#  56  SDP                                112123 non-null  float64
#  57  DKP_per_minute                     92725 non-null   object
#  58  FDP_per_minute                     92725 non-null   object
#  59  SDP_per_minute                     92725 non-null   object
#  60  pf_per_minute                      92724 non-null   float64
#  61  ts                                 112123 non-null  float64
#  62  last_60_minutes_per_game_starting  109403 non-null  float64
#  63  last_60_minutes_per_game_bench     109403 non-null  float64
#  64  PG%                                111976 non-null  float64
#  65  SG%                                111976 non-null  float64
#  66  SF%                                111976 non-null  float64
#  67  PF%                                111976 non-null  float64
#  68  C%                                 111976 non-null  float64
#  69  active_position_minutes            97003 non-null   float64
# dtypes: float64(36), int64(26), object(8)
# memory usage: 59.9+ MB
