# %%
import numpy as np
import pandas as pd
import requests
import json
import os 
opensecretsapi = os.getenv('opensecretsApi')
r = requests.get("https://httpbin.org/user-agent")
useragent = json.loads(r.text)["user-agent"]

# %%
states = ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
root = 'http://www.opensecrets.org/api'
df_total = pd.DataFrame()
for i in states:
    endpoint  = f"/?method=getLegislators&id={i}"
    print(root+endpoint)
    parameters = {'output':'json',
                  'apikey': opensecretsapi
                 }
    r = requests.get(root+endpoint,
                params = parameters)
    stateLegistors = json.loads(r.text)
    data = stateLegistors["response"]["legislator"]
    new_data = []
    for j in data:
        new_data.append(j["@attributes"])
    df_temp  = pd.DataFrame.from_dict(new_data)

    df_total = pd.concat([df_total, df_temp],ignore_index = True)
# Out:
# http://www.opensecrets.org/api/?method=getLegislators&id=AK
# http://www.opensecrets.org/api/?method=getLegislators&id=AL
# http://www.opensecrets.org/api/?method=getLegislators&id=AR
# http://www.opensecrets.org/api/?method=getLegislators&id=AZ
# http://www.opensecrets.org/api/?method=getLegislators&id=CA
# http://www.opensecrets.org/api/?method=getLegislators&id=CO
# http://www.opensecrets.org/api/?method=getLegislators&id=CT
# http://www.opensecrets.org/api/?method=getLegislators&id=DE
# http://www.opensecrets.org/api/?method=getLegislators&id=FL
# http://www.opensecrets.org/api/?method=getLegislators&id=GA
# http://www.opensecrets.org/api/?method=getLegislators&id=HI
# http://www.opensecrets.org/api/?method=getLegislators&id=IA
# http://www.opensecrets.org/api/?method=getLegislators&id=ID
# http://www.opensecrets.org/api/?method=getLegislators&id=IL
# http://www.opensecrets.org/api/?method=getLegislators&id=IN
# http://www.opensecrets.org/api/?method=getLegislators&id=KS
# http://www.opensecrets.org/api/?method=getLegislators&id=KY
# http://www.opensecrets.org/api/?method=getLegislators&id=LA
# http://www.opensecrets.org/api/?method=getLegislators&id=MA
# http://www.opensecrets.org/api/?method=getLegislators&id=MD
# http://www.opensecrets.org/api/?method=getLegislators&id=ME
# http://www.opensecrets.org/api/?method=getLegislators&id=MI
# http://www.opensecrets.org/api/?method=getLegislators&id=MN
# http://www.opensecrets.org/api/?method=getLegislators&id=MO
# http://www.opensecrets.org/api/?method=getLegislators&id=MS
# http://www.opensecrets.org/api/?method=getLegislators&id=MT
# http://www.opensecrets.org/api/?method=getLegislators&id=NC
# http://www.opensecrets.org/api/?method=getLegislators&id=ND
# http://www.opensecrets.org/api/?method=getLegislators&id=NE
# http://www.opensecrets.org/api/?method=getLegislators&id=NH
# http://www.opensecrets.org/api/?method=getLegislators&id=NJ
# http://www.opensecrets.org/api/?method=getLegislators&id=NM
# http://www.opensecrets.org/api/?method=getLegislators&id=NV
# http://www.opensecrets.org/api/?method=getLegislators&id=NY
# http://www.opensecrets.org/api/?method=getLegislators&id=OH
# http://www.opensecrets.org/api/?method=getLegislators&id=OK
# http://www.opensecrets.org/api/?method=getLegislators&id=OR
# http://www.opensecrets.org/api/?method=getLegislators&id=PA
# http://www.opensecrets.org/api/?method=getLegislators&id=RI
# http://www.opensecrets.org/api/?method=getLegislators&id=SC
# http://www.opensecrets.org/api/?method=getLegislators&id=SD
# http://www.opensecrets.org/api/?method=getLegislators&id=TN
# http://www.opensecrets.org/api/?method=getLegislators&id=TX
# http://www.opensecrets.org/api/?method=getLegislators&id=UT
# http://www.opensecrets.org/api/?method=getLegislators&id=VA
# http://www.opensecrets.org/api/?method=getLegislators&id=VT
# http://www.opensecrets.org/api/?method=getLegislators&id=WA
# http://www.opensecrets.org/api/?method=getLegislators&id=WI
# http://www.opensecrets.org/api/?method=getLegislators&id=WV
# http://www.opensecrets.org/api/?method=getLegislators&id=WY

# %%
df_total
# Out:
#            cid             firstlast   lastname party office gender  \
# 0    N00050780          Mary Peltola    Peltola     D   AK01      F
# 1    N00035774          Dan Sullivan   Sullivan     R   AKS1      M
# 2    N00026050        Lisa Murkowski  Murkowski     R   AKS2      F
# 3    N00044245            Jerry Carl       Carl     R   AL01      M
# 4    N00041295           Barry Moore      Moore     R   AL02      M
# ..         ...                   ...        ...   ...    ...    ...
# 532  N00032838           Joe Manchin    Manchin     D   WVS1      M
# 533  N00009771  Shelley Moore Capito     Capito     R   WVS2      F
# 534  N00049197       Harriet Hageman    Hageman     R   WY01      F
# 535  N00006236         John Barrasso   Barrasso     R   WYS1      M
# 536  N00029788        Cynthia Lummis     Lummis     R   WYS2      F
#
#     first_elected exit_code comments         phone  ...  \
# 0            2022         0                         ...
# 1            2014         0           202-224-3004  ...
# 2            2002         0           202-224-6665  ...
# 3            2020         0            202225-4931  ...
# 4            2020         0            202225-2901  ...
# ..            ...       ...      ...           ...  ...
# 532          2010         0           202-224-3954  ...
# 533          2014         0           202-224-6472  ...
# 534          2022         0                         ...
# 535          2007         0           202-224-6441  ...
# 536          2020         0           202-225-2311  ...
#
#                                    website  \
# 0
# 1          https://www.sullivan.senate.gov
# 2         https://www.murkowski.senate.gov
# 3                  https://carl.house.gov/
# 4            https://barrymoore.house.gov/
# ..                                     ...
# 532  https://www.manchin.senate.gov/public
# 533          https://www.capito.senate.gov
# 534
# 535        https://www.barrasso.senate.gov
# 536                http://lummis.house.gov
#
#                                                webform  \
# 0
# 1        https://www.sullivan.senate.gov/contact/email
# 2    https://www.murkowski.senate.gov/public/index....
# 3
# 4
# ..                                                 ...
# 532  http://www.manchin.senate.gov/public/index.cfm...
# 533  https://www.capito.senate.gov/contact/contact-...
# 534
# 535  https://www.barrasso.senate.gov/public/index.c...
# 536                   http://lummis.house.gov/contact/
#
#                                        congress_office bioguide_id  \
# 0
# 1                      702 Hart Senate Office Building     S001198
# 2                      522 Hart Senate Office Building     M001153
# 3    1330 Longworth House Office Building, Washingt...     C001054
# 4    1504 Longworth House Office Building, Washingt...     M001212
# ..                                                 ...         ...
# 532                    306 Hart Senate Office Building     M001183
# 533                 172 Russell Senate Office Building     C001047
# 534                                                        H001096
# 535                 307 Dirksen Senate Office Building     B001261
# 536                 2433 Rayburn House Office Building     L000571
#
#     votesmart_id  feccandid       twitter_id  \
# 0
# 1                 S4AK00214   SenDanSullivan
# 2          15841  S4AK00099    LisaMurkowski
# 3                              @RepJerryCarl
# 4                             @RepBarryMoore
# ..           ...        ...              ...
# 532         7547  S0WV00090   Sen_JoeManchin
# 533        11701  H0WV02138        SenCapito
# 534               H2WY00166
# 535        52662  S6WY00068  SenJohnBarrasso
# 536        15546  H8WY00148    CynthiaLummis
#
#                                       youtube_url       facebook_id  \
# 0
# 1                                                    SenDanSullivan
# 2            https://youtube.com/senatormurkowski  SenLisaMurkowski
# 3                                                      RepJerryCarl
# 4
# ..                                            ...               ...
# 532         https://youtube.com/SenatorJoeManchin     JoeManchinIII
# 533  https://youtube.com/UCbiXdR4XQ3vD9Xp5lfR9QXw        senshelley
# 534
# 535               https://youtube.com/barrassowyo      johnbarrasso
# 536              http://youtube.com/CynthiaLummis
#
#       birthdate
# 0
# 1    1964-11-13
# 2    1957-05-22
# 3      06/17/58
# 4      09/02/66
# ..          ...
# 532  1947-08-24
# 533  1953-11-26
# 534
# 535  1952-07-21
# 536  1954-09-10
#
# [537 rows x 21 columns]

# %%
cid = df_total.query("lastname == 'Good'")['cid']
cid = cid[496]
cid
# Out:
# 'N00045557'

# %%
root = 'http://www.opensecrets.org/api'
endpoint  = f"/?method=candContrib&cid={cid}&cycle=2022"
parameters = {'output':'json',
                  'apikey': opensecretsapi
                 }
r = requests.get(root+endpoint,
                params = parameters)
contributors = json.loads(r.text)

# %%
new_list = []
for i in contributors["response"]["contributors"]["contributor"]:
    new_list.append(i['@attributes'])

df_contributor = pd.DataFrame.from_dict(new_list)

# %%
df_contributor
# Out:
#                     org_name  total   pacs indivs
# 0         House Freedom Fund  33200  10000  23200
# 1              Rst Marketing  13500      0  13500
# 2  Dimensional Fund Advisors  11600      0  11600
# 3      Kinsale Capital Group  11600      0  11600
# 4          Marcus Foundation  11600      0  11600
# 5     Western National Group  11600      0  11600
# 6          Majority Cmte PAC  10000  10000      0
# 7         Prescott Investors   9108      0   9108
# 8            Station Casinos   8324      0   8324
# 9      Gun Owners of America   7500   7500      0
